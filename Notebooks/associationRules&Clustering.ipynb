# %%
# !pip install mlxtend networkx
# !pip install wordcloud
# !pip install hdbscan

# %%
# --- Celda de Imports para Modelado ---
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# Para Reglas de Asociación
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
import networkx as nx

# Para Clustering
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler

# Configuraciones de visualización
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 7)
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 12

# --- Cargar los datos preprocesados ---
data_path = Path("data/processed_for_modeling")
#Datos de playlist full
df_playlist = pd.read_parquet(data_path / "df_playlist_full.parquet")


#Datos para Reglas de Asociación
df_transactions = pd.read_parquet(data_path / "transactions_matrix.parquet")

# Datos para Clustering de Playlist
playlist_pca = pd.read_parquet(data_path / "playlist_pca_components.parquet")
playlist_umap = pd.read_parquet(data_path / "playlist_umap_embedding.parquet")

# DataFrame completo para agregación a nivel de playlist
playlist_for_clustering = pd.read_parquet(data_path / "playlist_for_clustering.parquet")

#Dataframe completo a nivel de tracks
df_processed_full = pd.read_parquet(data_path / "df_processed_full.parquet")

print("Datos cargados exitosamente.")
# print(f"Matriz de transacciones shape: {df_transactions.shape}")
print(f"DataFrame para clustering de playlist shape: {playlist_pca.shape}")
# Out:
# Datos cargados exitosamente.
# DataFrame para clustering de playlist shape: (8192, 10)

# %%
#trayendo los tracks
df_processed = pd.read_parquet(data_path / "df_processed_full.parquet")
print(f"DataFrame de tracks shape: {df_processed.shape}")
# Out:
# DataFrame de tracks shape: (124096, 65)

# %%
columns_to_drop = ["name", "artist_name", "track_name", "duration_ms", "album_name", "track_id"]
playlist_for_clustering = playlist_for_clustering.drop(columns=columns_to_drop)

print(f"DataFrame for playlist clustering after dropping columns: {playlist_for_clustering.shape}")
# Out:
# DataFrame for playlist clustering after dropping columns: (8192, 63)

# %%
playlist_for_clustering.head()
# Out:
#               bpm    energy  danceability_ll  loudness  \
# pid
# 1000000  0.160221  0.674865        -0.575001 -0.010197
# 1000016  0.163519 -0.810939        -0.626563  0.125442
# 1000020 -1.077283 -0.688983         0.546987  0.640798
# 1000023  0.241503 -0.266371        -0.454821 -0.155309
# 1000040  0.323022 -0.178108         1.983277  0.820105
#
#          danceability_danceable  gender_female  genre_dortmund_alternative  \
# pid
# 1000000                0.712000       0.890641                   -0.498757
# 1000016                0.868356       0.476394                   -0.066965
# 1000020                0.783371      -1.097435                    0.774962
# 1000023                0.863899       0.889459                   -0.545234
# 1000040                0.844329       0.954552                   -0.688467
#
#          genre_dortmund_blues  genre_dortmund_electronic  \
# pid
# 1000000             -0.430456                   0.519981
# 1000016             -0.304414                   0.348512
# 1000020              0.549553                  -0.859564
# 1000023             -0.502872                   0.626467
# 1000040             -0.529099                   0.678053
#
#          genre_dortmund_folkcountry  ...  mood_relaxed_relaxed  mood_sad_sad  \
# pid                                  ...
# 1000000                   -0.481145  ...              1.130548      0.525529
# 1000016                   -0.315390  ...              0.761068      0.333386
# 1000020                    0.816959  ...              0.255334     -0.652246
# 1000023                   -0.511086  ...              0.814086     -0.971319
# 1000040                   -0.525163  ...              0.536261     -0.100615
#
#          moods_mirex_Cluster1  moods_mirex_Cluster2  moods_mirex_Cluster3  \
# pid
# 1000000              0.893153              0.420956             -0.730197
# 1000016              0.225041              0.561850             -0.327078
# 1000020             -0.605235              0.161703             -0.469690
# 1000023              0.251995             -0.396421             -0.242822
# 1000040             -0.792774              0.123877              0.279067
#
#          moods_mirex_Cluster4  moods_mirex_Cluster5  timbre_bright  \
# pid
# 1000000              1.004184             -0.387829      -1.441935
# 1000016              0.033352             -0.169638       0.538302
# 1000020              2.516636             -0.905760       0.377803
# 1000023              1.161871             -0.155746      -0.384361
# 1000040              1.727907             -0.806363       1.160039
#
#          tonal_atonal_atonal  voice_instrumental_voice
# pid
# 1000000             1.124915                  0.680423
# 1000016             0.921453                  0.575065
# 1000020             0.092759                  0.883734
# 1000023             1.143995                  0.408990
# 1000040             1.001671                 -0.930150
#
# [5 rows x 63 columns]

# %%
playlist_pca.head()
# Out:
#              PC_1      PC_2      PC_3      PC_4      PC_5      PC_6      PC_7  \
# pid
# 1000000 -0.663803 -0.631957  4.806233  2.348698 -1.628967 -0.781611  3.238690
# 1000016 -1.349871  0.000669  0.607624 -0.475811  1.879978  2.161518 -2.195647
# 1000020  0.233109  4.628954 -0.889581  0.257637 -0.817259  0.401576 -0.180352
# 1000023 -3.502215  0.524163 -0.833910 -0.632196 -1.481683  0.398017 -0.946594
# 1000040 -0.979415 -1.463812  0.872277  0.829315  0.013625  2.956005 -0.203531
#
#              PC_8      PC_9     PC_10
# pid
# 1000000  1.171119 -2.040517  2.240854
# 1000016  0.174255  0.376852  0.624177
# 1000020  0.579727  0.363847  0.005663
# 1000023  4.065633 -1.825655 -1.087756
# 1000040 -0.288747 -0.247835  0.576816

# %% [markdown]
# # 5: Clustering (Agrupación)
# Dividiremos esta sección en dos partes, como se discutió: clustering de tracks y de playlists.
#
# **Parte A: Clustering a Nivel de playlist **
#
#
# ## 5.A.1 Algoritmo 1: K-Means con Búsqueda de K Óptimo

# %%
# --- 5.A.1 K-Means (Versión Corregida) ---
# Usamos el método del codo (Elbow Method) para encontrar un buen valor para k

X_playlist = playlist_umap.copy() # Datos de entrada originales

# --- LA CORRECCIÓN ESTÁ AQUÍ ---
# K-Means solo puede trabajar con números. Nos aseguramos de seleccionar solo las columnas numéricas.
# El error 'could not convert string to float: 'Party'' indica que columnas de texto se colaron.
X_playlist_numeric = X_playlist.select_dtypes(include=np.number)

print(f"Shape original de X_playlist: {X_playlist.shape}")
print(f"Shape de X_playlist_numeric (solo columnas numéricas): {X_playlist_numeric.shape}\n")


# --- Continuación del código original, usando el DataFrame NUMÉRICO ---
inertia = []
K_range = range(2, 16) # Probaremos con k de 2 a 15

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    # Usamos el DataFrame NUMÉRICO para el ajuste
    kmeans.fit(X_playlist_numeric)
    inertia.append(kmeans.inertia_)

# Graficar el codo
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, marker='o', linestyle='--')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del Codo para encontrar k Óptimo')
plt.xticks(K_range)
plt.show()
# Out:
# Shape original de X_playlist: (8192, 2)
# Shape de X_playlist_numeric (solo columnas numéricas): (8192, 2)

# %% [markdown]
# ## 5.A.2 Algoritmos 2 y 3: DBSCAN y Agglomerative Clustering (reemplazado x MiniBatchKMeans)

# %%
# Basado en el gráfico, elegimos un valor para k (ej. k=9 donde la curva se aplana)
import hdbscan
OPTIMAL_K = 6
kmeans = KMeans(n_clusters=OPTIMAL_K, random_state=42, n_init=10)
# Usamos el DataFrame NUMÉRICO aquí también
playlist_labels_kmeans = kmeans.fit_predict(X_playlist_numeric)

print(f"\nClustering con K-Means completado usando k={OPTIMAL_K}.")
# --- 5.A.2 Algoritmos 2 y 3: DBSCAN y MiniBatchKMeans (CORREGIDO Y OPTIMIZADO) ---

# --- DBSCAN ---
# DBSCAN puede ser lento en datasets grandes. Sus hiperparámetros son clave.
# Si esta parte también es muy lenta, considera ejecutarla sobre una muestra o ajustar 'eps'.
print("Ejecutando DBSCAN...")
dbscan = DBSCAN(eps=2.5, min_samples=20, n_jobs=-1) # n_jobs=-1 usa todos los núcleos de tu CPU
playlist_labels_dbscan = dbscan.fit_predict(X_playlist_numeric)
print("DBSCAN completado.")

# ---HDBSCAN ---
print("Ejecutando HDBSCAN...")
hdbscan = hdbscan.HDBSCAN(min_cluster_size=20, min_samples=20, gen_min_span_tree=True)
playlist_labels_hdbscan = hdbscan.fit_predict(X_playlist_numeric)
print("HDBSCAN completado.")


# --- MiniBatchKMeans (Reemplazo eficiente para Agglomerative Clustering) ---
# Este algoritmo es mucho más rápido y consume muchísima menos memoria.
print("Ejecutando MiniBatchKMeans...")
mini_batch_kmeans = MiniBatchKMeans(
    n_clusters=OPTIMAL_K, # Usamos el mismo k que en KMeans
    random_state=42,
    batch_size=256, # Tamaño del lote, un hiperparámetro a ajustar
    n_init=10
)
playlist_labels_minibatch = mini_batch_kmeans.fit_predict(X_playlist_numeric)
print("MiniBatchKMeans completado.")
# Out:
# /usr/local/lib/python3.11/dist-packages/hdbscan/plots.py:448: DeprecationWarning: invalid escape sequence '\l'
#   axis.set_ylabel('$\lambda$ value')
# /usr/local/lib/python3.11/dist-packages/hdbscan/robust_single_linkage_.py:154: DeprecationWarning: invalid escape sequence '\{'
#   """Perform robust single linkage clustering from a vector array
# Clustering con K-Means completado usando k=6.
# Ejecutando DBSCAN...
# DBSCAN completado.
# Ejecutando HDBSCAN...
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# HDBSCAN completado.
# Ejecutando MiniBatchKMeans...
# MiniBatchKMeans completado.

# %% [markdown]
# # --- 5.A.3 Evaluación Comparativa y Visualización

# %%
# --- 5.A.3 Evaluación Comparativa y Visualización (ACTUALIZADO CON HDBSCAN) ---
print("\nCalculando métricas de evaluación...")

# ------------------------------------------------------------------
# 1. K‑Means
# ------------------------------------------------------------------
score_s_kmeans  = silhouette_score(X_playlist_numeric, playlist_labels_kmeans)
score_db_kmeans = davies_bouldin_score(X_playlist_numeric, playlist_labels_kmeans)

# ------------------------------------------------------------------
# 2. DBSCAN  (excluyendo ruido)
# ------------------------------------------------------------------
print("Evaluando DBSCAN...")
mask_dbscan = playlist_labels_dbscan != -1        # Filtra ruido

if len(set(playlist_labels_dbscan[mask_dbscan])) > 1:
    sample_size = min(20_000, np.sum(mask_dbscan))

    X_reset = X_playlist_numeric.reset_index(drop=True)
    sample_idx = np.random.choice(X_reset[mask_dbscan].index,
                                  size=sample_size, replace=False)

    score_s_dbscan  = silhouette_score(X_reset.loc[sample_idx],
                                       playlist_labels_dbscan[sample_idx])
    score_db_dbscan = davies_bouldin_score(X_reset.loc[sample_idx],
                                           playlist_labels_dbscan[sample_idx])
else:
    print("DBSCAN no encontró suficientes clusters para ser evaluado.")
    score_s_dbscan  = -1
    score_db_dbscan = -1

# ------------------------------------------------------------------
# 3. HDBSCAN  (excluyendo ruido)
# ------------------------------------------------------------------
print("Evaluando HDBSCAN...")
mask_hdbscan = playlist_labels_hdbscan != -1      # Filtra ruido

if len(set(playlist_labels_hdbscan[mask_hdbscan])) > 1:
    sample_size = min(20_000, np.sum(mask_hdbscan))

    sample_idx = np.random.choice(X_reset[mask_hdbscan].index,
                                  size=sample_size, replace=False)

    score_s_hdbscan  = silhouette_score(X_reset.loc[sample_idx],
                                        playlist_labels_hdbscan[sample_idx])
    score_db_hdbscan = davies_bouldin_score(X_reset.loc[sample_idx],
                                            playlist_labels_hdbscan[sample_idx])
else:
    print("HDBSCAN no encontró suficientes clusters para ser evaluado.")
    score_s_hdbscan  = -1
    score_db_hdbscan = -1

# ------------------------------------------------------------------
# 4. MiniBatch K‑Means
# ------------------------------------------------------------------
print("Evaluando MiniBatchKMeans...")
score_s_minibatch  = silhouette_score(X_playlist_numeric, playlist_labels_minibatch)
score_db_minibatch = davies_bouldin_score(X_playlist_numeric, playlist_labels_minibatch)

# ------------------------------------------------------------------
# Tabla de resultados
# ------------------------------------------------------------------
results = pd.DataFrame({
    'Algoritmo': [
        'K‑Means',
        'DBSCAN',
        'HDBSCAN',
        'MiniBatchKMeans'
    ],
    'Silhouette Score (más alto es mejor)': [
        score_s_kmeans,
        score_s_dbscan,
        score_s_hdbscan,
        score_s_minibatch
    ],
    'Davies‑Bouldin Score (más bajo es mejor)': [
        score_db_kmeans,
        score_db_dbscan,
        score_db_hdbscan,
        score_db_minibatch
    ]
})

print("\n--- Tabla Comparativa de Modelos de Clustering de playlist ---")
display(results)

# (tu código de visualización permanece igual)
# Out:
# Calculando métricas de evaluación...
# Evaluando DBSCAN...
# Evaluando HDBSCAN...
# Evaluando MiniBatchKMeans...
#
# --- Tabla Comparativa de Modelos de Clustering de playlist ---
#          Algoritmo  Silhouette Score (más alto es mejor)  \
# 0          K‑Means                              0.388025
# 1           DBSCAN                              0.358953
# 2          HDBSCAN                              0.619507
# 3  MiniBatchKMeans                              0.359695
#
#    Davies‑Bouldin Score (más bajo es mejor)
# 0                                  0.851140
# 1                                  0.340665
# 2                                  0.460246
# 3                                  0.888194

# %% [markdown]
# # 5.A.3 Evaluación Comparativa y Visualización

# %%
# --- Visualización de Clusters ---
# Este bloque no necesita cambios, pero lo mantenemos por completitud.
# Muestra los resultados de K-Means como ejemplo.
# Nota: Para visualizar otros resultados, simplemente cambia 'track_labels_kmeans'
# por 'track_labels_minibatch' o 'track_labels_dbscan'.

print("\nGenerando visualización de clusters (ejemplo con K-Means)...")
viz_df = playlist_umap.copy()
viz_df['cluster'] = playlist_labels_kmeans

plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=viz_df,
    x='UMAP_1',
    y='UMAP_2',
    hue='cluster',
    palette=sns.color_palette("hsv", n_colors=OPTIMAL_K),
    s=10, # Tamaño de los puntos
    alpha=0.7,
    legend='full'
)
plt.title(f'Visualización de Clusters de Canciones (K-Means, k={OPTIMAL_K})')
plt.show()
# Out:
# Generando visualización de clusters (ejemplo con K-Means)...

# %%
# --- Visualización de Clusters con HDBSCAN ---

print("\nGenerando visualización de clusters (ejemplo con K-Means)...")
viz_df = playlist_umap.copy()
viz_df['cluster'] = playlist_labels_hdbscan

# --- FIX START ---
# Use np.unique() to get unique values from a numpy array
unique_clusters = np.unique(playlist_labels_hdbscan)
# Ensure there are unique clusters before determining n_colors
n_colors = len(unique_clusters) if len(unique_clusters) > 0 else 1
print(n_colors)
# --- FIX END ---


plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=viz_df,
    x='UMAP_1',
    y='UMAP_2',
    hue='cluster',
    palette=sns.color_palette("hsv", n_colors=n_colors), # Use the corrected n_colors
    s=10, # Tamaño de los puntos
    alpha=0.7,
    legend='full'
)
plt.title(f'Visualización de Clusters de Canciones HDBscan')
plt.show()
# Out:
# Generando visualización de clusters (ejemplo con K-Means)...
# 83

# %%
df_playlist['playlist_labels_hdbscan'] = playlist_labels_hdbscan
df_playlist["playlist_labels_kmeans"] = playlist_labels_kmeans
print("\nEtiquetas de HDBSCAN añadidas a df_playlist.")

if 'name_x' in df_playlist.columns:
    # Renombra la columna 'name_x' a 'name'
    df_playlist.rename(columns={'name_x': 'name'}, inplace=True)

if 'name_y' in df_playlist.columns:
    # Elimina la columna 'name_y'
    df_playlist.drop("name_y", axis=1, inplace=True)

df_playlist.head()
# Out:
# Etiquetas de HDBSCAN añadidas a df_playlist.
#         pid   avg_bpm  avg_energy  avg_danceability_ll  avg_loudness  \
# 0   1000000 -0.158348    0.396294            -0.700306      0.125202
# 3   1000001 -0.512764    0.251691             0.040809     -0.416864
# 14  1000009  0.417665    0.803308            -0.719781     -0.689314
# 19  1000016 -0.502793   -0.661331            -0.120105      0.180342
# 22  1000020 -1.077283   -0.688983             0.546987      0.640798
#
#     danceability_danceable  gender_female  genre_dortmund_alternative  \
# 0                 0.363061       0.371108                   -0.484566
# 3                -0.915044       0.089547                   -0.372681
# 14               -0.952088      -0.402470                    0.134985
# 19                0.682097      -0.612838                   -0.260205
# 22                0.783371      -1.097435                    0.774962
#
#     genre_dortmund_blues  genre_dortmund_electronic  ...  \
# 0              -0.361109                   0.435491  ...
# 3              -0.116873                   0.381763  ...
# 14              1.360055                  -0.896558  ...
# 19             -0.319518                   0.375747  ...
# 22              0.549553                  -0.859564  ...
#
#     moods_mirex_Cluster4  moods_mirex_Cluster5  timbre_bright  \
# 0               0.455781              0.067093      -0.735381
# 3              -0.632964              0.527874       0.203971
# 14              0.240725             -0.944949       0.086277
# 19              0.626471             -0.656781       0.861908
# 22              2.516636             -0.905760       0.377803
#
#     tonal_atonal_atonal  voice_instrumental_voice  total_duration_ms  \
# 0              1.052521                  0.084001             523715
# 3              0.131274                 -0.285914            3294637
# 14            -0.089870                  0.502085             948799
# 19            -0.326220                  0.386508             594092
# 22             0.092759                  0.883734             187720
#
#     n_tracks          name  playlist_labels_hdbscan  playlist_labels_kmeans
# 0          3         Party                       13                       0
# 3         10        Oldies                       38                       1
# 14         5   Study Music                       -1                       3
# 19         3        school                       33                       5
# 22         1  Modern Music                       -1                       1
#
# [5 rows x 69 columns]

# %% [markdown]
# #probando una tercera opción: clusters híbridos
#
# vemos que hdbscan funciona muy bien porque separa los outliers, pero con kmeans ganamos interpretabilidad, vamos a poner los outliers como un solo grupo y separar el resto en k's con kmeans

# %%
playlist_umap["playlist_labels_hdbscan"] = playlist_labels_hdbscan

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.cluster import KMeans, HDBSCAN
from collections import Counter
import matplotlib.pyplot as plt # Import matplotlib.pyplot

# Intentar importar XGBoost si está disponible
try:
    from xgboost import XGBClassifier
    XGBOOST_AVAILABLE = True
except ImportError:
    XGBOOST_AVAILABLE = False
    print("⚠️ XGBoost no está instalado. Usando alternativas de sklearn.")

df = playlist_umap
feature_columns=  X_playlist_numeric.columns
n_clusters_kmeans=6
min_cluster_size=20

"""
Aplica HDBSCAN para detectar outliers y luego K-Means al resto
"""
print("=== CLUSTERING HÍBRIDO HDBSCAN + K-MEANS ===\n")

# Preparar datos
X = df[feature_columns].copy()

# Escalado robusto (mejor para outliers)
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# 1. HDBSCAN para detectar outliers
print("Paso 1: Aplicando HDBSCAN para detectar outliers...")
hdbscan_clusterer = HDBSCAN(
    min_cluster_size=min_cluster_size,
    min_samples=10,
    cluster_selection_epsilon=0.5,
    metric='euclidean'
)

hdbscan_labels = hdbscan_clusterer.fit_predict(X_scaled)

# Estadísticas HDBSCAN
outliers_mask = hdbscan_labels == -1
n_outliers = np.sum(outliers_mask)
n_clusters_hdbscan = len(set(hdbscan_labels)) - (1 if -1 in hdbscan_labels else 0)

print(f"  - Outliers detectados: {n_outliers} ({n_outliers/len(df)*100:.1f}%)")
print(f"  - Clusters HDBSCAN: {n_clusters_hdbscan}")

# 2. K-Means solo en datos no-outliers
print(f"\nPaso 2: Aplicando K-Means con {n_clusters_kmeans} clusters a datos no-outliers...")


non_outliers_data = X_scaled[~outliers_mask]
non_outliers_indices = np.where(~outliers_mask)[0]

if len(non_outliers_data) == 0:
    print("⚠️ Todos los datos fueron clasificados como outliers!")


# --- Continuación del código original, usando el DataFrame NUMÉRICO ---
inertia = []
K_range = range(2, 16) # Probaremos con k de 2 a 15

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    # Usamos el DataFrame NUMÉRICO para el ajuste
    # --- FIX START ---
    kmeans.fit(non_outliers_data) # Use non_outliers_data here
    # --- FIX END ---
    inertia.append(kmeans.inertia_)

# Graficar el codo
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, marker='o', linestyle='--')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del Codo para encontrar k Óptimo (en inliers)') # Added context
plt.xticks(K_range)
plt.show()



kmeans = KMeans(
    n_clusters=n_clusters_kmeans,
    random_state=42,
    n_init=10,
    max_iter=300
)
# --- FIX START ---
kmeans_labels_subset = kmeans.fit_predict(non_outliers_data) # Use non_outliers_data here
# --- FIX END ---

# 3. Crear labels finales
# --- FIX START ---
# Initialize with a distinct value (e.g., -1 or a new class label)
final_labels = np.full(len(df), n_clusters_kmeans)
# Assign K-Means labels to the non-outlier indices
final_labels[non_outliers_indices] = kmeans_labels_subset
# --- FIX END ---


# 4. Agregar resultados al DataFrame
df_result = df.copy()
df_result['cluster_hybrid'] = final_labels
df_result['is_outlier'] = outliers_mask

# 5. Estadísticas finales
print(f"\n=== RESULTADOS CLUSTERING HÍBRIDO ===")
cluster_counts = Counter(final_labels)

# --- FIX START ---
# Print counts for each cluster, including outliers
for label in sorted(cluster_counts.keys()):
    if label == n_clusters_kmeans:
         print(f"Outliers (cluster  {n_clusters_kmeans}): {cluster_counts[label]} playlists")

    else:
        print(f"Cluster {label}: {cluster_counts[label]} playlists")
# --- FIX END ---


# Calcular métricas de calidad
# --- FIX START ---
# Calculate metrics only for inliers where K-Means was applied
if len(set(kmeans_labels_subset)) > 1: # Check if K-Means found more than one cluster
    sil_score = silhouette_score(non_outliers_data, kmeans_labels_subset)
    db_score = davies_bouldin_score(non_outliers_data, kmeans_labels_subset)
    print(f"\nSilhouette Score (solo K-Means en inliers): {sil_score:.4f}")
    print(f"Davies-Bouldin Score (solo K-Means en inliers): {db_score:.4f}")
else:
    print("\nSilhouette Score (solo K-Means en inliers): No se encontraron suficientes clusters.")
    print("Davies-Bouldin Score (solo K-Means en inliers): No se encontraron suficientes clusters.")
# --- FIX END ---

df_result.head()
# Out:
# === CLUSTERING HÍBRIDO HDBSCAN + K-MEANS ===
#
# Paso 1: Aplicando HDBSCAN para detectar outliers...
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_hdbscan/hdbscan.py:857: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   self.labels_, self.probabilities_ = tree_to_labels(
#   - Outliers detectados: 41 (0.5%)
#   - Clusters HDBSCAN: 11
#
# Paso 2: Aplicando K-Means con 6 clusters a datos no-outliers...
# === RESULTADOS CLUSTERING HÍBRIDO ===
# Cluster 0: 272 playlists
# Cluster 1: 1930 playlists
# Cluster 2: 438 playlists
# Cluster 3: 709 playlists
# Cluster 4: 2180 playlists
# Cluster 5: 2622 playlists
# Outliers (cluster  6): 41 playlists
#
# Silhouette Score (solo K-Means en inliers): 0.3912
# Davies-Bouldin Score (solo K-Means en inliers): 0.8500
#             UMAP_1    UMAP_2  playlist_labels_hdbscan  cluster_hybrid  \
# pid
# 1000000  17.085173 -0.839397                       13               2
# 1000016   6.023946  3.598349                       38               4
# 1000020   8.524440  1.867325                       -1               5
# 1000023   9.937390  6.673456                       33               1
# 1000040   4.498182  0.070753                       -1               4
#
#          is_outlier
# pid
# 1000000       False
# 1000016       False
# 1000020       False
# 1000023       False
# 1000040       False

# %%
df_playlist["cluster_hybrid"] = final_labels
df_playlist.head()
# Out:
#         pid   avg_bpm  avg_energy  avg_danceability_ll  avg_loudness  \
# 0   1000000 -0.158348    0.396294            -0.700306      0.125202
# 3   1000001 -0.512764    0.251691             0.040809     -0.416864
# 14  1000009  0.417665    0.803308            -0.719781     -0.689314
# 19  1000016 -0.502793   -0.661331            -0.120105      0.180342
# 22  1000020 -1.077283   -0.688983             0.546987      0.640798
#
#     danceability_danceable  gender_female  genre_dortmund_alternative  \
# 0                 0.363061       0.371108                   -0.484566
# 3                -0.915044       0.089547                   -0.372681
# 14               -0.952088      -0.402470                    0.134985
# 19                0.682097      -0.612838                   -0.260205
# 22                0.783371      -1.097435                    0.774962
#
#     genre_dortmund_blues  genre_dortmund_electronic  ...  \
# 0              -0.361109                   0.435491  ...
# 3              -0.116873                   0.381763  ...
# 14              1.360055                  -0.896558  ...
# 19             -0.319518                   0.375747  ...
# 22              0.549553                  -0.859564  ...
#
#     moods_mirex_Cluster5  timbre_bright  tonal_atonal_atonal  \
# 0               0.067093      -0.735381             1.052521
# 3               0.527874       0.203971             0.131274
# 14             -0.944949       0.086277            -0.089870
# 19             -0.656781       0.861908            -0.326220
# 22             -0.905760       0.377803             0.092759
#
#     voice_instrumental_voice  total_duration_ms  n_tracks          name  \
# 0                   0.084001             523715         3         Party
# 3                  -0.285914            3294637        10        Oldies
# 14                  0.502085             948799         5   Study Music
# 19                  0.386508             594092         3        school
# 22                  0.883734             187720         1  Modern Music
#
#     playlist_labels_hdbscan  playlist_labels_kmeans  cluster_hybrid
# 0                        13                       0               2
# 3                        38                       1               4
# 14                       -1                       3               5
# 19                       33                       5               1
# 22                       -1                       1               4
#
# [5 rows x 70 columns]

# %% [markdown]
# vamos a definir los clusters un poco para interpretar mejor los datos

# %% [markdown]
# ##Descripción de los clusters

# %%
cluster_column = 'cluster_hybrid'

fig, axes = plt.subplots(1, 3, figsize=(15, 3))

# Distribución de clusters
cluster_counts = df_playlist[cluster_column].value_counts().sort_index()
# Corrected: Use single index for axes
axes[0].bar(cluster_counts.index, cluster_counts.values, color='skyblue', alpha=0.7)
axes[0].set_title('Distribución de Playlists por Cluster')
axes[0].set_xlabel('Cluster')
axes[0].set_ylabel('Número de Playlists')

# Duración promedio por cluster
duration_by_cluster = df_playlist.groupby(cluster_column)['total_duration_ms'].mean() / 60000
# Corrected: Use single index for axes
axes[1].bar(duration_by_cluster.index, duration_by_cluster.values, color='lightgreen', alpha=0.7)
axes[1].set_title('Duración Promedio por Cluster (minutos)')
axes[1].set_xlabel('Cluster')
axes[1].set_ylabel('Duración (min)')

# Número de tracks promedio por cluster
tracks_by_cluster = df_playlist.groupby(cluster_column)['n_tracks'].mean()
# Corrected: Use single index for axes
axes[2].bar(tracks_by_cluster.index, tracks_by_cluster.values, color='lightcoral', alpha=0.7)
axes[2].set_title('Número Promedio de Tracks por Cluster')
axes[2].set_xlabel('Cluster')
axes[2].set_ylabel('Número de Tracks')


plt.tight_layout()
plt.show()

# %%
# columnas que realmente quieres describir
core = ['avg_bpm','avg_energy','avg_danceability_ll','avg_loudness',"gender_female",
        'genre_dortmund_electronic','genre_dortmund_rock','genre_dortmund_pop',
        'genre_tzanetakis_cla','mood_party_party','mood_relaxed_relaxed',
        'timbre_bright','tonal_atonal_atonal',]

feat_df = df_playlist[core + [cluster_column]]

# 1) centroides
centroids = feat_df.groupby(cluster_column).mean()

# 2) media y std global
global_mean = feat_df[core].mean()
global_std  = feat_df[core].std(ddof=0)

# 3) z‑scores del centroide ─ valores >0 ⇒ sobre el promedio
zcent = (centroids - global_mean) / global_std

# 4) quedarnos con top ±5 variables más “extremas” por cluster
summary = {}
for c, row in zcent.iterrows():
    top_pos = row.sort_values(ascending=False).head(5)
    top_neg = row.sort_values().head(5)
    summary[c] = pd.concat([top_pos, top_neg])

summary_df = (pd.concat(summary, axis=1)
                .rename_axis('feature')
                .T.reset_index()
                .rename(columns={'level_0':'cluster'}))

# %%
import seaborn as sns, matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(zcent[core], cmap='RdYlBu_r', center=0, annot=False)
plt.title("Z‑score de atributos clave por cluster")
plt.show()

# %%
import math
from wordcloud import WordCloud

# Filter out playlists with "sin nombre" (case insensitive)
df_filtered = df_playlist[~df_playlist['name'].str.lower().str.contains('sin nombre', na=False)]

# Join all names for each cluster (excluding "sin nombre")
all_names = df_filtered.groupby(cluster_column)['name'].apply(lambda x: ' '.join(x))

# Determine the number of clusters
num_clusters = len(all_names)

# Determine the number of rows and columns for the plot
ncols = 3
nrows = math.ceil(num_clusters / ncols)

# Create the figure and axes
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, nrows * 5)) # Adjust figsize as needed

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Generate and plot word clouds for each cluster in the subplots
for i, (cluster_label, names) in enumerate(all_names.items()):
    # Check if there are any names after filtering
    if names.strip():  # Only create wordcloud if there are actual names
        wordcloud = WordCloud(width = 800, height = 800,
                              background_color ='white',
                              stopwords = set(), # Add stopwords if needed
                              min_font_size = 10,
                              max_words = 100,  # Limit number of words for better readability
                              relative_scaling = 0.5,  # Better word scaling
                              random_state = 42).generate(names)  # For reproducible results

        # plot the WordCloud image on the correct subplot
        axes[i].imshow(wordcloud)
        axes[i].axis("off")

        # Get count of playlists in this cluster (after filtering)
        cluster_count = len(df_filtered[df_filtered[cluster_column] == cluster_label])
        original_count = len(df_playlist[df_playlist[cluster_column] == cluster_label])

        axes[i].set_title(f'Cluster {cluster_label}\n({cluster_count} playlists)', fontsize=14)
    else:
        # If no names after filtering, show a message
        axes[i].text(0.5, 0.5, f'Cluster {cluster_label}\nNo named playlists',
                    ha='center', va='center', fontsize=12,
                    bbox=dict(boxstyle="round,pad=0.3", facecolor="lightgray"))
        axes[i].set_xlim(0, 1)
        axes[i].set_ylim(0, 1)
        axes[i].axis("off")

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=2.0) # Adjust padding between subplots
plt.suptitle('Word Clouds for Playlist Clusters (Excluding "Sin Nombre")', fontsize=20, y=1.02) # Add a main title
plt.show()

# Optional: Print some statistics about the filtering
print("=== ESTADÍSTICAS DE FILTRADO ===")
print(f"Total playlists originales: {len(df_playlist)}")
print(f"Playlists con 'sin nombre': {len(df_playlist) - len(df_filtered)}")
print(f"Playlists después del filtro: {len(df_filtered)}")
print(f"Porcentaje filtrado: {((len(df_playlist) - len(df_filtered)) / len(df_playlist) * 100):.1f}%")

print("\n=== PLAYLISTS POR CLUSTER (DESPUÉS DEL FILTRO) ===")
for cluster in sorted(df_filtered[cluster_column].unique()):
    original_count = len(df_playlist[df_playlist[cluster_column] == cluster])
    filtered_count = len(df_filtered[df_filtered[cluster_column] == cluster])
    print(f"Cluster {cluster}: {filtered_count} playlists (era {original_count})")
# Out:
# === ESTADÍSTICAS DE FILTRADO ===
# Total playlists originales: 8192
# Playlists con 'sin nombre': 1883
# Playlists después del filtro: 6309
# Porcentaje filtrado: 23.0%
#
# === PLAYLISTS POR CLUSTER (DESPUÉS DEL FILTRO) ===
# Cluster 0: 204 playlists (era 272)
# Cluster 1: 1494 playlists (era 1930)
# Cluster 2: 347 playlists (era 438)
# Cluster 3: 536 playlists (era 709)
# Cluster 4: 1646 playlists (era 2180)
# Cluster 5: 2048 playlists (era 2622)
# Cluster 6: 34 playlists (era 41)

# %% [markdown]
# # 4: Reglas de Asociación con kmeans
# Vamos a hacer reglas de asociación dentro de los clusters para definirlos

# %%
track_meta = (df_processed
              .drop_duplicates('track_id')
              .set_index('track_id')
              .loc[:, ['track_name', 'artist_name', 'bpm', "energy", "bpm"]]
              .to_dict('index'))
def enrich_rule(row):
    ant_id  = next(iter(row['antecedents']))
    cons_id = next(iter(row['consequents']))
    ant_meta  = track_meta.get(ant_id, {})
    cons_meta = track_meta.get(cons_id, {})
    return pd.Series({
        "A_id": ant_id,
        "A_name": ant_meta.get('track_name'),
        "A_artist": ant_meta.get('artist_name'),
        "A_bpm": ant_meta.get('bpm'),
        "A_energy": ant_meta.get('energy'),
        "A_bpm" : ant_meta.get('bpm'),
        "B_id": cons_id,
        "B_name": cons_meta.get('track_name'),
        "B_artist": cons_meta.get('artist_name'),
        "B_bpm": cons_meta.get('bpm'),
        "B_energy": cons_meta.get('energy'),
        "B_bpm" : cons_meta.get('bpm'),
        "support": row['support'],
        "confidence": row['confidence'],
        "lift": row['lift']
    })
# Out:
# /tmp/ipython-input-28-3782691971.py:5: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   .to_dict('index'))

# %%
# 0) merge para que cada track sepa a qué cluster pertenece su playlist
tracks_w_cluster = (
    df_processed
      .merge(df_playlist[['pid', cluster_column]], on='pid', how='inner')
)

# 1) función auxiliar ─────────
def rules_for_cluster(df_cluster,
                      min_playlists=5,
                      min_support=0.0005,
                      min_lift=1.2,
                      top_n=25):

    n_play = df_cluster['pid'].nunique()
    abs_sup = max(min_playlists, int(min_support * n_play))
    rel_sup = abs_sup / n_play

    basket = (df_cluster.assign(val=True)
              .pivot_table(index='pid', columns='track_id',
                           values='val', aggfunc='max', fill_value=False)
              .astype(bool))

    # Mantén solo ítems que superan el soporte absoluto
    item_sup = basket.sum()
    basket   = basket.loc[:, item_sup >= abs_sup]
    if basket.shape[1] < 2:       # no hay pares posibles
        return pd.DataFrame()

    itemsets = fpgrowth(basket, min_support=rel_sup,
                        use_colnames=True, max_len=2)
    if itemsets.empty:
        return pd.DataFrame()

    rules = (association_rules(itemsets, metric='lift',
                               min_threshold=min_lift)
             .query('confidence < 0.95')        # filtra reglas “perfectas”
             .sort_values('lift', ascending=False)
             .head(top_n))
    return rules.reset_index(drop=True)

# 2) recorrer los 7 clusters ───────────────────
rules_by_cluster = {}

for c in sorted(tracks_w_cluster[cluster_column].unique()):
    print(f"\n⏳ Procesando cluster {c} …")
    # Use the cluster labels directly from the merged DataFrame
    subset = tracks_w_cluster[ tracks_w_cluster[cluster_column] == c ]

    # Dynamically adjust min_support based on the number of playlists in the cluster
    num_playlists_in_cluster = subset['pid'].nunique()
    # A possible heuristic: decrease min_support for smaller clusters
    # For example, if the average number of playlists is X, and a cluster has X/2 playlists,
    # you might halve the min_support for that cluster.
    # Let's start with a simple approach: min_support is inversely proportional to the number of playlists,
    # but with a lower bound to avoid finding too many trivial rules.
    base_min_support = 0.003 # Starting point
    min_support_c = max(0.0005, base_min_support * (num_playlists_in_cluster / tracks_w_cluster['pid'].nunique())) # Ensure a minimum support

    print(f"  Número de playlists en cluster {c}: {num_playlists_in_cluster}")
    print(f"  Usando min_support: {min_support_c:.4f}")


    rules_c = rules_for_cluster(subset,
                                min_support=min_support_c,  # adjusted min_support
                                min_lift=1.3,
                                top_n=30)
    rules_readable = rules_c.apply(enrich_rule, axis=1)
    rules_by_cluster[c] = rules_c

    print(f"✓ Cluster {c}: {len(rules_c)} reglas guardadas.")
# Out:
# ⏳ Procesando cluster 0 …
#   Número de playlists en cluster 0: 272
#   Usando min_support: 0.0005
# ✓ Cluster 0: 3 reglas guardadas.
#
# ⏳ Procesando cluster 1 …
#   Número de playlists en cluster 1: 1930
#   Usando min_support: 0.0007
# ✓ Cluster 1: 30 reglas guardadas.
#
# ⏳ Procesando cluster 2 …
#   Número de playlists en cluster 2: 438
#   Usando min_support: 0.0005
# ✓ Cluster 2: 28 reglas guardadas.
#
# ⏳ Procesando cluster 3 …
#   Número de playlists en cluster 3: 709
#   Usando min_support: 0.0005
# ✓ Cluster 3: 30 reglas guardadas.
#
# ⏳ Procesando cluster 4 …
#   Número de playlists en cluster 4: 2180
#   Usando min_support: 0.0008
# ✓ Cluster 4: 30 reglas guardadas.
#
# ⏳ Procesando cluster 5 …
#   Número de playlists en cluster 5: 2622
#   Usando min_support: 0.0010
# ✓ Cluster 5: 30 reglas guardadas.
#
# ⏳ Procesando cluster 6 …
#   Número de playlists en cluster 6: 41
#   Usando min_support: 0.0005
# ✓ Cluster 6: 0 reglas guardadas.

# %%
# --- 0) diccionario de metadatos básicos -----------------------
meta_cols = ['track_name', 'artist_name', 'bpm']
track_meta = (df_processed
              .drop_duplicates('track_id')
              .set_index('track_id')[meta_cols]
              .to_dict('index'))

def stringify(tid_set):
    """Convierte {id} o {id1,id2} → 'Name1 • Name2'."""
    names = [track_meta[tid]['track_name']
             if tid in track_meta else tid
             for tid in tid_set]
    return " • ".join(names)

def enrich_rules(rules_df):
    """Añade columnas legibles aún si hay ≥1 ids en antecedente/consecuente."""
    rules_df = rules_df.copy()
    rules_df['A_ids']  = rules_df['antecedents'].apply(list)
    rules_df['B_ids']  = rules_df['consequents'].apply(list)

    # nombres y artistas concatenados
    rules_df['A_names'] = rules_df['A_ids'].apply(lambda lst: " / ".join(
        [track_meta[i]['track_name']  if i in track_meta else i for i in lst]))
    rules_df['B_names'] = rules_df['B_ids'].apply(lambda lst: " / ".join(
        [track_meta[i]['track_name']  if i in track_meta else i for i in lst]))
    rules_df['A_artists'] = rules_df['A_ids'].apply(lambda lst: " / ".join(
        [track_meta[i]['artist_name'] if i in track_meta else "?" for i in lst]))
    rules_df['B_artists'] = rules_df['B_ids'].apply(lambda lst: " / ".join(
        [track_meta[i]['artist_name'] if i in track_meta else "?" for i in lst]))

    # ejemplo de atributo numérico medio (BPM) para antecedente
    rules_df['A_bpm_avg'] = rules_df['A_ids'].apply(
        lambda lst: np.mean([track_meta[i]['bpm'] for i in lst if i in track_meta]))

    return (rules_df
            .loc[:, ['A_names','A_artists','B_names','B_artists',
                     'support','confidence','lift']])

# Ejemplo para el cluster 2
for i in range (0, OPTIMAL_K):
    print(f"Cluster {i}:")
    if i in rules_by_cluster and len(rules_by_cluster[i])>0:
      readable_c2 = enrich_rules(rules_by_cluster[i])
      display(readable_c2)
    else:
      print(f"No hay reglas para el cluster {i}.")
# Out:
# Cluster 0:
#          A_names     A_artists        B_names     B_artists   support  \
# 0  XO TOUR Llif3  Lil Uzi Vert  Tunnel Vision   Kodak Black  0.025735
# 1  XO TOUR Llif3  Lil Uzi Vert   Come Get Her  Rae Sremmurd  0.018382
# 2   Come Get Her  Rae Sremmurd  XO TOUR Llif3  Lil Uzi Vert  0.018382
#
#    confidence       lift
# 0    0.636364  24.727273
# 1    0.454545  20.606061
# 2    0.833333  20.606061
# Cluster 1:
#                                               A_names             A_artists  \
# 0                                              Voodoo              Godsmack
# 1                                        Oxford Comma       Vampire Weekend
# 2                                        Put It On Me               Ja Rule
# 3                                           Mesmerize               Ja Rule
# 4                                     Brown Paper Bag                 Migos
# 5                    Kelly Price (feat. Travis Scott)                 Migos
# 6                                Smoke a Little Smoke           Eric Church
# 7   The Only Way I Know (with Luke Bryan and Eric ...          Jason Aldean
# 8                                              Castle                Halsey
# 9                                              Colors                Halsey
# 10                      It Don't Hurt Like It Used To      Billy Currington
# 11                                            Alright         Darius Rucker
# 12                                          Come Over         Kenny Chesney
# 13              Huntin', Fishin' And Lovin' Every Day            Luke Bryan
# 14                                          21 Summer      Brothers Osborne
# 15                                What Was I Thinkin'        Dierks Bentley
# 16                                            Cocaine          Eric Clapton
# 17                     Won't Get Fooled Again - Remix               The Who
# 18                                       She Hates Me        Puddle Of Mudd
# 19                                         Confession  Florida Georgia Line
# 20                                             Voodoo              Godsmack
# 21                                         Summertime         Kenny Chesney
# 22                                   Get Right Witcha                 Migos
# 23                   Kelly Price (feat. Travis Scott)                 Migos
# 24                      We Will Rock You - Remastered                 Queen
# 25                             Rock And Roll All Nite                  KISS
# 26              Message In A Bottle - Remastered 2003            The Police
# 27                                 Smoke On the Water           Deep Purple
# 28                                           Your Man           Josh Turner
# 29                                         RGF Island             Fetty Wap
#
#                                               B_names         B_artists  \
# 0                                       I Stand Alone          Godsmack
# 1                                        Mansard Roof   Vampire Weekend
# 2                                           Mesmerize           Ja Rule
# 3                                        Put It On Me           Ja Rule
# 4                    Kelly Price (feat. Travis Scott)             Migos
# 5                                     Brown Paper Bag             Migos
# 6   The Only Way I Know (with Luke Bryan and Eric ...      Jason Aldean
# 7                                Smoke a Little Smoke       Eric Church
# 8                                              Colors            Halsey
# 9                                              Castle            Halsey
# 10                                         Seein' Red      Dustin Lynch
# 11                                          Come Over     Kenny Chesney
# 12                                            Alright     Darius Rucker
# 13                                          21 Summer  Brothers Osborne
# 14              Huntin', Fishin' And Lovin' Every Day        Luke Bryan
# 15                                         Summertime     Kenny Chesney
# 16                     Won't Get Fooled Again - Remix           The Who
# 17                                            Cocaine      Eric Clapton
# 18                                             Voodoo          Godsmack
# 19                                        Mind Reader      Dustin Lynch
# 20                                       She Hates Me    Puddle Of Mudd
# 21                                What Was I Thinkin'    Dierks Bentley
# 22                   Kelly Price (feat. Travis Scott)             Migos
# 23                                   Get Right Witcha             Migos
# 24              Message In A Bottle - Remastered 2003        The Police
# 25                                 Smoke On the Water       Deep Purple
# 26                      We Will Rock You - Remastered             Queen
# 27                             Rock And Roll All Nite              KISS
# 28                                       Time Is Love       Josh Turner
# 29                                 Jugg (feat. Monty)         Fetty Wap
#
#      support  confidence        lift
# 0   0.003109    0.750000  241.250000
# 1   0.002591    0.555556  214.444444
# 2   0.002591    0.714286  196.938776
# 3   0.002591    0.714286  196.938776
# 4   0.002591    0.833333  160.833333
# 5   0.002591    0.500000  160.833333
# 6   0.002591    0.625000  150.781250
# 7   0.002591    0.625000  150.781250
# 8   0.002591    0.714286  137.857143
# 9   0.002591    0.500000  137.857143
# 10  0.002591    0.357143  137.857143
# 11  0.002591    0.555556  134.027778
# 12  0.002591    0.625000  134.027778
# 13  0.002591    0.454545  125.324675
# 14  0.002591    0.714286  125.324675
# 15  0.002591    0.500000  120.625000
# 16  0.002591    0.500000  120.625000
# 17  0.002591    0.625000  120.625000
# 18  0.002591    0.500000  120.625000
# 19  0.002591    0.312500  120.625000
# 20  0.002591    0.625000  120.625000
# 21  0.002591    0.625000  120.625000
# 22  0.003109    0.600000  115.800000
# 23  0.003109    0.600000  115.800000
# 24  0.002591    0.357143  114.880952
# 25  0.002591    0.357143  114.880952
# 26  0.002591    0.833333  114.880952
# 27  0.002591    0.833333  114.880952
# 28  0.003109    0.461538  111.346154
# 29  0.003109    0.461538  111.346154
# Cluster 2:
#                            A_names             A_artists  \
# 0   Country Girl (Shake It For Me)            Luke Bryan
# 1                           Cruise  Florida Georgia Line
# 2          That's My Kind Of Night            Luke Bryan
# 3                 Kick The Dust Up            Luke Bryan
# 4                        Talladega           Eric Church
# 5                   Drinking class             Lee Brice
# 6                            Swang          Rae Sremmurd
# 7                            Swang          Rae Sremmurd
# 8                        Talladega           Eric Church
# 9                        Talladega           Eric Church
# 10         That's My Kind Of Night            Luke Bryan
# 11                Kick The Dust Up            Luke Bryan
# 12                    Come Get Her          Rae Sremmurd
# 13           I Don't Fuck With You              Big Sean
# 14                           Swang          Rae Sremmurd
# 15                  Too Many Years           Kodak Black
# 16                           Swang          Rae Sremmurd
# 17                     It's A Vibe              2 Chainz
# 18                This Could Be Us          Rae Sremmurd
# 19                    Come Get Her          Rae Sremmurd
# 20                          Closer      The Chainsmokers
# 21                        You & Me         Marc E. Bassy
# 22                   White Iverson           Post Malone
# 23                        Caroline                 Aminé
# 24                    Come Get Her          Rae Sremmurd
# 25                           Swang          Rae Sremmurd
# 26                    Come Get Her          Rae Sremmurd
# 27                   White Iverson           Post Malone
#
#                            B_names             B_artists   support  \
# 0                           Cruise  Florida Georgia Line  0.011416
# 1   Country Girl (Shake It For Me)            Luke Bryan  0.011416
# 2                 Kick The Dust Up            Luke Bryan  0.013699
# 3          That's My Kind Of Night            Luke Bryan  0.013699
# 4                   Drinking class             Lee Brice  0.011416
# 5                        Talladega           Eric Church  0.011416
# 6                         Low Life                Future  0.011416
# 7                pick up the phone            Young Thug  0.013699
# 8                 Kick The Dust Up            Luke Bryan  0.011416
# 9          That's My Kind Of Night            Luke Bryan  0.011416
# 10                       Talladega           Eric Church  0.011416
# 11                       Talladega           Eric Church  0.011416
# 12           I Don't Fuck With You              Big Sean  0.011416
# 13                    Come Get Her          Rae Sremmurd  0.011416
# 14                  Too Many Years           Kodak Black  0.011416
# 15                           Swang          Rae Sremmurd  0.011416
# 16                     It's A Vibe              2 Chainz  0.011416
# 17                           Swang          Rae Sremmurd  0.011416
# 18                    Come Get Her          Rae Sremmurd  0.011416
# 19                This Could Be Us          Rae Sremmurd  0.011416
# 20                        You & Me         Marc E. Bassy  0.011416
# 21                          Closer      The Chainsmokers  0.011416
# 22                        Caroline                 Aminé  0.011416
# 23                   White Iverson           Post Malone  0.011416
# 24                           Swang          Rae Sremmurd  0.013699
# 25                    Come Get Her          Rae Sremmurd  0.013699
# 26                   White Iverson           Post Malone  0.011416
# 27                    Come Get Her          Rae Sremmurd  0.011416
#
#     confidence       lift
# 0     0.714286  52.142857
# 1     0.833333  52.142857
# 2     0.750000  41.062500
# 3     0.750000  41.062500
# 4     0.555556  34.761905
# 5     0.714286  34.761905
# 6     0.384615  33.692308
# 7     0.461538  33.692308
# 8     0.555556  30.416667
# 9     0.555556  30.416667
# 10    0.625000  30.416667
# 11    0.625000  30.416667
# 12    0.384615  28.076923
# 13    0.833333  28.076923
# 14    0.384615  28.076923
# 15    0.833333  28.076923
# 16    0.384615  24.065934
# 17    0.714286  24.065934
# 18    0.555556  18.717949
# 19    0.384615  18.717949
# 20    0.384615  16.846154
# 21    0.500000  16.846154
# 22    0.357143  15.642857
# 23    0.500000  15.642857
# 24    0.461538  15.550296
# 25    0.461538  15.550296
# 26    0.384615  12.032967
# 27    0.357143  12.032967
# Cluster 3:
#                                               A_names  \
# 0                            I Like The Sound Of That
# 1                                  Leave The Night On
# 2                                          Summertime
# 3                                                Dirt
# 4                        Even If It Breaks Your Heart
# 5                                      Colder Weather
# 6                                       American Kids
# 7                                  Somewhere With You
# 8                                          Summertime
# 9                                        Drunk On You
# 10                                      Play It Again
# 11                                 Leave The Night On
# 12                                     Take Your Time
# 13                                   Get Right Witcha
# 14  Perfect Pint (feat. Kendrick Lamar, Gucci Mane...
# 15                             Sugar, We're Goin Down
# 16                                Dirty Little Secret
# 17  Perfect Pint (feat. Kendrick Lamar, Gucci Mane...
# 18                                       Throw Sum Mo
# 19                                              Moves
# 20                                       Back To Back
# 21                                          Big Rings
# 22                                           Ass Drop
# 23                                            So Sick
# 24                                          Suga Suga
# 25                                      XO TOUR Llif3
# 26                                      Tunnel Vision
# 27                                           2 Phones
# 28                                         Jimmy Choo
# 29                                           2 Phones
#
#                    A_artists  \
# 0              Rascal Flatts
# 1                   Sam Hunt
# 2              Kenny Chesney
# 3       Florida Georgia Line
# 4             Eli Young Band
# 5             Zac Brown Band
# 6              Kenny Chesney
# 7              Kenny Chesney
# 8              Kenny Chesney
# 9                 Luke Bryan
# 10                Luke Bryan
# 11                  Sam Hunt
# 12                  Sam Hunt
# 13                     Migos
# 14         Mike WiLL Made-It
# 15              Fall Out Boy
# 16  The All-American Rejects
# 17         Mike WiLL Made-It
# 18              Rae Sremmurd
# 19                  Big Sean
# 20                     Drake
# 21                     Drake
# 22               Wiz Khalifa
# 23                     Ne-Yo
# 24                 Baby Bash
# 25              Lil Uzi Vert
# 26               Kodak Black
# 27               Kevin Gates
# 28                 Fetty Wap
# 29               Kevin Gates
#
#                                               B_names  \
# 0                                         Mind Reader
# 1                                                Dirt
# 2                        Even If It Breaks Your Heart
# 3                                  Leave The Night On
# 4                                          Summertime
# 5                                       American Kids
# 6                                      Colder Weather
# 7                                          Summertime
# 8                                  Somewhere With You
# 9                                       Play It Again
# 10                                       Drunk On You
# 11                                     Take Your Time
# 12                                 Leave The Night On
# 13  Perfect Pint (feat. Kendrick Lamar, Gucci Mane...
# 14                                   Get Right Witcha
# 15                                Dirty Little Secret
# 16                             Sugar, We're Goin Down
# 17                                              Moves
# 18                                           Ass Drop
# 19  Perfect Pint (feat. Kendrick Lamar, Gucci Mane...
# 20                                          Big Rings
# 21                                       Back To Back
# 22                                       Throw Sum Mo
# 23                                          Suga Suga
# 24                                            So Sick
# 25                                      Tunnel Vision
# 26                                      XO TOUR Llif3
# 27                                         Jimmy Choo
# 28                                           2 Phones
# 29                                          I Mean It
#
#                    B_artists   support  confidence       lift
# 0               Dustin Lynch  0.007052    0.625000  88.625000
# 1       Florida Georgia Line  0.007052    0.625000  73.854167
# 2             Eli Young Band  0.007052    0.625000  73.854167
# 3                   Sam Hunt  0.007052    0.833333  73.854167
# 4              Kenny Chesney  0.007052    0.833333  73.854167
# 5              Kenny Chesney  0.008463    0.750000  66.468750
# 6             Zac Brown Band  0.008463    0.750000  66.468750
# 7              Kenny Chesney  0.007052    0.714286  63.303571
# 8              Kenny Chesney  0.007052    0.625000  63.303571
# 9                 Luke Bryan  0.007052    0.714286  56.269841
# 10                Luke Bryan  0.007052    0.555556  56.269841
# 11                  Sam Hunt  0.008463    0.750000  53.175000
# 12                  Sam Hunt  0.008463    0.600000  53.175000
# 13         Mike WiLL Made-It  0.007052    0.625000  49.236111
# 14                     Migos  0.007052    0.555556  49.236111
# 15  The All-American Rejects  0.008463    0.545455  48.340909
# 16              Fall Out Boy  0.008463    0.750000  48.340909
# 17                  Big Sean  0.007052    0.555556  43.765432
# 18               Wiz Khalifa  0.007052    0.555556  43.765432
# 19         Mike WiLL Made-It  0.007052    0.555556  43.765432
# 20                     Drake  0.007052    0.555556  43.765432
# 21                     Drake  0.007052    0.555556  43.765432
# 22              Rae Sremmurd  0.007052    0.555556  43.765432
# 23                 Baby Bash  0.007052    0.625000  36.927083
# 24                     Ne-Yo  0.007052    0.416667  36.927083
# 25               Kodak Black  0.008463    0.461538  36.358974
# 26              Lil Uzi Vert  0.008463    0.666667  36.358974
# 27                 Fetty Wap  0.008463    0.375000  33.234375
# 28               Kevin Gates  0.008463    0.750000  33.234375
# 29                    G-Eazy  0.008463    0.375000  20.451923
# Cluster 4:
#                          A_names          A_artists  \
# 0                        Happier         Ed Sheeran
# 1               March To The Sea  Twenty One Pilots
# 2               March To The Sea  Twenty One Pilots
# 3                       Hometown  Twenty One Pilots
# 4                         Screen  Twenty One Pilots
# 5                        Duality           Slipknot
# 6                        Duality           Slipknot
# 7               Freak On a Leash               Korn
# 8                Before I Forget           Slipknot
# 9                      I Go Back      Kenny Chesney
# 10                        Screen  Twenty One Pilots
# 11                       Duality           Slipknot
# 12                  Fake You Out  Twenty One Pilots
# 13                 Coming Undone               Korn
# 14                  Fairly Local  Twenty One Pilots
# 15                      Lane Boy  Twenty One Pilots
# 16                     Remind Me       Brad Paisley
# 17                        Wolves         Kanye West
# 18            Cowboys and Angels       Dustin Lynch
# 19                           FML         Kanye West
# 20                         Audi.         Smokepurpp
# 21                      Hometown  Twenty One Pilots
# 22                        Screen  Twenty One Pilots
# 23                          Boss           Lil Pump
# 24                         Saved             Khalid
# 25  You Really Got Me - Mono Mix          The Kinks
# 26         Sunshine Of Your Love              Cream
# 27     Setting the World On Fire      Kenny Chesney
# 28                      Migraine  Twenty One Pilots
# 29                 House Of Gold  Twenty One Pilots
#
#                            B_names          B_artists   support  confidence  \
# 0   Hearts Don't Break Around Here         Ed Sheeran  0.002294    0.555556
# 1                           Screen  Twenty One Pilots  0.002294    0.833333
# 2                         Hometown  Twenty One Pilots  0.002294    0.833333
# 3                 March To The Sea  Twenty One Pilots  0.002294    0.625000
# 4                 March To The Sea  Twenty One Pilots  0.002294    0.625000
# 5                  Before I Forget           Slipknot  0.002294    0.714286
# 6                 Freak On a Leash               Korn  0.002294    0.714286
# 7                          Duality           Slipknot  0.002294    0.714286
# 8                          Duality           Slipknot  0.002294    0.714286
# 9        Never Wanted Nothing More      Kenny Chesney  0.002294    0.454545
# 10                    Fake You Out  Twenty One Pilots  0.002294    0.625000
# 11                   Coming Undone               Korn  0.002294    0.714286
# 12                          Screen  Twenty One Pilots  0.002294    0.714286
# 13                         Duality           Slipknot  0.002294    0.625000
# 14                        Lane Boy  Twenty One Pilots  0.002752    0.750000
# 15                    Fairly Local  Twenty One Pilots  0.002752    0.666667
# 16              Cowboys and Angels       Dustin Lynch  0.002294    0.833333
# 17                             FML         Kanye West  0.002294    0.500000
# 18                       Remind Me       Brad Paisley  0.002294    0.500000
# 19                          Wolves         Kanye West  0.002294    0.833333
# 20                            Boss           Lil Pump  0.002294    0.625000
# 21                          Screen  Twenty One Pilots  0.002294    0.625000
# 22                        Hometown  Twenty One Pilots  0.002294    0.625000
# 23                           Audi.         Smokepurpp  0.002294    0.625000
# 24                    Cold Blooded             Khalid  0.002294    0.384615
# 25           Sunshine Of Your Love              Cream  0.002294    0.714286
# 26    You Really Got Me - Mono Mix          The Kinks  0.002294    0.500000
# 27                           Noise      Kenny Chesney  0.002294    0.555556
# 28                   House Of Gold  Twenty One Pilots  0.002294    0.833333
# 29                        Migraine  Twenty One Pilots  0.002294    0.416667
#
#           lift
# 0   242.222222
# 1   227.083333
# 2   227.083333
# 3   227.083333
# 4   227.083333
# 5   222.448980
# 6   222.448980
# 7   222.448980
# 8   222.448980
# 9   198.181818
# 10  194.642857
# 11  194.642857
# 12  194.642857
# 13  194.642857
# 14  181.666667
# 15  181.666667
# 16  181.666667
# 17  181.666667
# 18  181.666667
# 19  181.666667
# 20  170.312500
# 21  170.312500
# 22  170.312500
# 23  170.312500
# 24  167.692308
# 25  155.714286
# 26  155.714286
# 27  151.388889
# 28  151.388889
# 29  151.388889
# Cluster 5:
#                                      A_names                A_artists  \
# 0                               Never Enough                    Logic
# 1   Jingle Bells (feat. The Puppini Sisters)            Michael Bublé
# 2              Santa Claus Is Coming To Town            Michael Bublé
# 3                                      Drive                   Halsey
# 4                                  Young God                   Halsey
# 5                                     Angela            The Lumineers
# 6                           Smoke Two Joints                  Sublime
# 7                                    Badfish                  Sublime
# 8                       Wrong Side Of Heaven  Five Finger Death Punch
# 9                                Bad Company  Five Finger Death Punch
# 10                                    Colors                   Halsey
# 11                                     Slide        The Goo Goo Dolls
# 12                                    Angela            The Lumineers
# 13                                  Gun Song            The Lumineers
# 14                            I Will Not Bow        Breaking Benjamin
# 15                                   Fake It                  Seether
# 16                                 wonderful             Travis Scott
# 17                               Bait A Hook             Justin Moore
# 18                                 No Option              Post Malone
# 19                      Broken Whiskey Glass              Post Malone
# 20                            Never Too Late         Three Days Grace
# 21                            I Will Not Bow        Breaking Benjamin
# 22                             Enter Sandman                Metallica
# 23               I Hate Everything About You         Three Days Grace
# 24                           Awake and Alive                  Skillet
# 25                      Smoke a Little Smoke              Eric Church
# 26                                  Creepin'              Eric Church
# 27                           More Than Miles         Brantley Gilbert
# 28                           Nobody To Blame          Chris Stapleton
# 29                                 Fire Away          Chris Stapleton
#
#                                      B_names                B_artists  \
# 0                               Innermission                    Logic
# 1              Santa Claus Is Coming To Town            Michael Bublé
# 2   Jingle Bells (feat. The Puppini Sisters)            Michael Bublé
# 3                                  Young God                   Halsey
# 4                                      Drive                   Halsey
# 5                               In The Light            The Lumineers
# 6                                    Badfish                  Sublime
# 7                           Smoke Two Joints                  Sublime
# 8                                Bad Company  Five Finger Death Punch
# 9                       Wrong Side Of Heaven  Five Finger Death Punch
# 10                                 Young God                   Halsey
# 11                             Black Balloon        The Goo Goo Dolls
# 12                                  Gun Song            The Lumineers
# 13                                    Angela            The Lumineers
# 14                                   Fake It                  Seether
# 15                            I Will Not Bow        Breaking Benjamin
# 16                                   outside             Travis Scott
# 17                     I Could Kick Your Ass             Justin Moore
# 18                      Broken Whiskey Glass              Post Malone
# 19                                 No Option              Post Malone
# 20                            I Will Not Bow        Breaking Benjamin
# 21                            Never Too Late         Three Days Grace
# 22                      Nothing Else Matters                Metallica
# 23                           Awake and Alive                  Skillet
# 24               I Hate Everything About You         Three Days Grace
# 25                                  Creepin'              Eric Church
# 26                      Smoke a Little Smoke              Eric Church
# 27                     Kick It In The Sticks         Brantley Gilbert
# 28                                 Fire Away          Chris Stapleton
# 29                           Nobody To Blame          Chris Stapleton
#
#      support  confidence        lift
# 0   0.001907    0.833333  437.000000
# 1   0.001907    0.833333  364.166667
# 2   0.001907    0.833333  364.166667
# 3   0.001907    0.714286  312.142857
# 4   0.001907    0.833333  312.142857
# 5   0.001907    0.555556  291.333333
# 6   0.001907    0.625000  273.125000
# 7   0.001907    0.833333  273.125000
# 8   0.002288    0.857143  224.742857
# 9   0.002288    0.600000  224.742857
# 10  0.002288    0.500000  218.500000
# 11  0.002288    0.500000  218.500000
# 12  0.001907    0.555556  208.095238
# 13  0.001907    0.714286  208.095238
# 14  0.001907    0.625000  204.843750
# 15  0.001907    0.625000  204.843750
# 16  0.002288    0.461538  201.692308
# 17  0.001907    0.384615  201.692308
# 18  0.001907    0.555556  182.083333
# 19  0.001907    0.625000  182.083333
# 20  0.002288    0.545455  178.772727
# 21  0.002288    0.750000  178.772727
# 22  0.003051    0.533333  174.800000
# 23  0.001907    0.454545  170.259740
# 24  0.001907    0.714286  170.259740
# 25  0.001907    0.384615  168.076923
# 26  0.001907    0.833333  168.076923
# 27  0.001907    0.500000  163.875000
# 28  0.001907    0.625000  163.875000
# 29  0.001907    0.500000  163.875000

# %%
n_rows = 2
n_cols = 3

# Crear la figura y los ejes para los subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 8, n_rows * 8)) # Ajusta el tamaño de la figura

# Aplanar la matriz de ejes para poder iterar fácilmente
axes = axes.flatten()

for i in range(OPTIMAL_K):
    # Seleccionar el eje actual
    ax = axes[i]

    if i in rules_by_cluster and not rules_by_cluster[i].empty:
        G = nx.from_pandas_edgelist(rules_by_cluster[i],
                                  source='antecedents',
                                  target='consequents',
                                  edge_attr=['lift', 'confidence'])
        # Posiciones de los nodos
        pos = nx.spring_layout(G, k=0.5, iterations=50)
        # Dibujar nodos y etiquetas en el eje actual
        nx.draw_networkx_nodes(G, pos, node_size=2000, node_color='skyblue', ax=ax)
        # Dibujar aristas con grosor basado en el lift en el eje actual
        edge_width = [d['lift'] * 0.5 for (u, v, d) in G.edges(data=True)]
        nx.draw_networkx_edges(G, pos, width=edge_width, edge_color='gray', alpha=0.7, ax=ax)
        ax.set_title(f'Red de Reglas en Cluster {i} (Top 20 por Lift)')
        ax.axis('off')
    else:
        ax.set_title(f'Cluster {i}: No hay reglas para visualizar')
        ax.axis('off')


# Ocultar los subplots restantes si hay menos de OPTIMAL_K gráficos
for j in range(OPTIMAL_K, n_rows * n_cols):
    fig.delaxes(axes[j])

plt.tight_layout() # Ajustar automáticamente los subplots para que no se solapen
plt.show()

# %%
df_playlist.head()
# Out:
#         pid   avg_bpm  avg_energy  avg_danceability_ll  avg_loudness  \
# 0   1000000 -0.158348    0.396294            -0.700306      0.125202
# 3   1000001 -0.512764    0.251691             0.040809     -0.416864
# 14  1000009  0.417665    0.803308            -0.719781     -0.689314
# 19  1000016 -0.502793   -0.661331            -0.120105      0.180342
# 22  1000020 -1.077283   -0.688983             0.546987      0.640798
#
#     danceability_danceable  gender_female  genre_dortmund_alternative  \
# 0                 0.363061       0.371108                   -0.484566
# 3                -0.915044       0.089547                   -0.372681
# 14               -0.952088      -0.402470                    0.134985
# 19                0.682097      -0.612838                   -0.260205
# 22                0.783371      -1.097435                    0.774962
#
#     genre_dortmund_blues  genre_dortmund_electronic  ...  \
# 0              -0.361109                   0.435491  ...
# 3              -0.116873                   0.381763  ...
# 14              1.360055                  -0.896558  ...
# 19             -0.319518                   0.375747  ...
# 22              0.549553                  -0.859564  ...
#
#     moods_mirex_Cluster5  timbre_bright  tonal_atonal_atonal  \
# 0               0.067093      -0.735381             1.052521
# 3               0.527874       0.203971             0.131274
# 14             -0.944949       0.086277            -0.089870
# 19             -0.656781       0.861908            -0.326220
# 22             -0.905760       0.377803             0.092759
#
#     voice_instrumental_voice  total_duration_ms  n_tracks          name  \
# 0                   0.084001             523715         3         Party
# 3                  -0.285914            3294637        10        Oldies
# 14                  0.502085             948799         5   Study Music
# 19                  0.386508             594092         3        school
# 22                  0.883734             187720         1  Modern Music
#
#     playlist_labels_hdbscan  playlist_labels_kmeans  cluster_hybrid
# 0                        13                       0               2
# 3                        38                       1               4
# 14                       -1                       3               5
# 19                       33                       5               1
# 22                       -1                       1               4
#
# [5 rows x 70 columns]

# %%
from pathlib import Path

# --- Crear un directorio para los datos procesados ---
output_dir = Path("data/processed_for_prediction")
output_dir.mkdir(parents=True, exist_ok=True)

print(f"Directorio de salida creado en: {output_dir}")


# --- Guardar los DataFrames esenciales ---

# 1. El Dataframe de playlist con los clusters demarcados

df_playlist.to_parquet(output_dir / "df_playlist_with_clusters.parquet", index=False)
print(f"df_playlist guardado en '{output_dir / 'df_playlist_with_clusters.parquet'}'")

# 1. El Dataframe de playlist con los clusters demarcados

df_playlist.to_parquet(output_dir / "df_playlist_with_clusters.parquet", index=False)
print(f"df_playlist guardado en '{output_dir / 'df_playlist_with_clusters.parquet'}'")

# 2. Playlist con UMAP
playlist_umap = playlist_umap.reset_index()  # deja 'pid' como columna
playlist_umap = playlist_umap.merge(
    df_playlist[['pid', 'playlist_labels_hdbscan', "cluster_hybrid"]],
    on='pid',
    how='left'
)
playlist_umap = playlist_umap.set_index('pid')  # si prefieres volver a indexar por pid

playlist_umap.to_parquet(output_dir / "playlist_umap.parquet")
print(f"playlist_umap guardado en '{output_dir / 'playlist_umap.parquet'}'")
# Out:
# Directorio de salida creado en: data/processed_for_prediction
# df_playlist guardado en 'data/processed_for_prediction/df_playlist_with_clusters.parquet'
# df_playlist guardado en 'data/processed_for_prediction/df_playlist_with_clusters.parquet'
# playlist_umap guardado en 'data/processed_for_prediction/playlist_umap.parquet'

# %% [markdown]
# ## 4.1 ✈ código de la versión anterior: Aplicar Algoritmos (Apriori y FP-Growth)
# Ambos algoritmos buscan conjuntos de ítems (canciones) frecuentes. La diferencia principal es su rendimiento; FP-Growth suele ser más rápido.
#
# El hiperparámetro clave aquí es min_support (soporte mínimo). Define la frecuencia mínima que debe tener un conjunto de canciones para ser considerado "frecuente". Un valor bajo encontrará más reglas pero tardará más. Empecemos con 0.005 (presente en al menos el 0.5% de las playlists)

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, fpgrowth
import gc
import psutil
import os

def get_memory_usage():
    """Obtiene el uso actual de memoria del proceso"""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / 1024 / 1024  # MB

def optimize_dataframe_memory(df):
    """Optimiza el uso de memoria del DataFrame"""
    print(f"Memoria inicial: {get_memory_usage():.2f} MB")

    # Convertir a sparse boolean con menor densidad
    s_bool = pd.SparseDtype("bool", fill_value=False)
    df_sparse = df.astype(s_bool)

    # Forzar garbage collection
    gc.collect()

    print(f"Memoria después de conversión sparse: {get_memory_usage():.2f} MB")
    return df_sparse

def filter_infrequent_items(df, min_support_items=0.001):
    """Elimina items que aparecen muy poco frecuentemente"""
    print("Filtrando items poco frecuentes...")

    # Calcular soporte de cada item individual
    item_support = df.sum() / len(df)

    # Mantener solo items que superen el umbral mínimo
    frequent_items = item_support[item_support >= min_support_items].index

    print(f"Items originales: {len(df.columns)}")
    print(f"Items frecuentes mantenidos: {len(frequent_items)}")

    return df[frequent_items]

def sample_transactions(df, sample_size=0.8, random_state=42):
    """Reduce el tamaño del dataset mediante muestreo"""
    if sample_size < 1.0:
        print(f"Aplicando muestreo: {sample_size*100}% de las transacciones")
        df_sampled = df.sample(frac=sample_size, random_state=random_state)
        print(f"Transacciones: {len(df)} -> {len(df_sampled)}")
        return df_sampled
    return df

def run_apriori_optimized(df_transactions, min_support=0.005, max_len=3):
    """
    Ejecuta Apriori con optimizaciones de memoria

    Parameters:
    - df_transactions: DataFrame con transacciones
    - min_support: Soporte mínimo
    - max_len: Longitud máxima de itemsets (limita memoria)
    """

    print("=== OPTIMIZACIÓN DE MEMORIA ===")

    # 1. Filtrar items poco frecuentes
    df_filtered = filter_infrequent_items(df_transactions, min_support_items=min_support/2)
    gc.collect()

    # 2. Aplicar muestreo si es necesario (ajusta según tu RAM)
    df_sampled = sample_transactions(df_filtered, sample_size=0.7)  # Usa el 70%
    gc.collect()

    # 3. Optimizar tipos de datos
    df_optimized = optimize_dataframe_memory(df_sampled)

    print("\n=== EJECUTANDO APRIORI ===")
    print(f"Dataset final: {df_optimized.shape}")
    print(f"Memoria antes de Apriori: {get_memory_usage():.2f} MB")

    try:
        # Usar low_memory=True y max_len para controlar memoria
        frequent_itemsets = apriori(
            df_optimized,
            min_support=min_support,
            use_colnames=True,
            verbose=1,
            low_memory=True,        # IMPORTANTE: activa modo de baja memoria
            max_len=max_len         # Limita la longitud máxima de itemsets
        )

        print(f"\n✅ Apriori completado exitosamente!")
        print(f"Conjuntos frecuentes encontrados: {len(frequent_itemsets)}")
        print(f"Memoria final: {get_memory_usage():.2f} MB")

        return frequent_itemsets

    except MemoryError:
        print("❌ Error de memoria con Apriori. Intentando con FP-Growth...")

def run_fpgrowth_alternative(df_optimized, min_support, max_len):
    """Alternativa usando FP-Growth con optimizaciones extremas"""
    print("Intentando FP-Growth con optimizaciones extremas...")

    # Reducir aún más el dataset
    print("Aplicando reducción extrema del dataset...")
    df_ultra_small = df_optimized.sample(frac=0.3, random_state=42)  # Solo 30%

    # Filtrar items aún más agresivamente
    item_support = df_ultra_small.sum() / len(df_ultra_small)
    very_frequent_items = item_support[item_support >= min_support * 2].index  # 2x más restrictivo
    df_ultra_filtered = df_ultra_small[very_frequent_items]

    print(f"Dataset ultra-reducido: {df_ultra_filtered.shape}")
    print(f"Memoria antes de FP-Growth: {get_memory_usage():.2f} MB")

    try:
        frequent_itemsets = fpgrowth(
            df_ultra_filtered,
            min_support=min_support * 1.5,  # Aumentar soporte mínimo
            use_colnames=True,
            verbose=1,
            max_len=min(max_len, 2)  # Máximo 2 items
        )

        print(f"✅ FP-Growth completado con dataset reducido!")
        print(f"Conjuntos frecuentes encontrados: {len(frequent_itemsets)}")
        return frequent_itemsets

    except Exception as e:
        print(f"❌ FP-Growth también falló: {e}")
        return None

# %%
# --- 4.1 Búsqueda de Ítems Frecuentes ---

# Hiperparámetro a ajustar
MIN_SUPPORT = 0.005

# --- Algoritmo 1: Apriori ---
print("Ejecutando Apriori...")

frequent_itemsets_apriori = run_apriori_optimized(
    df_transactions,
    min_support=0.005,
    max_len=3
)
print(f"Apriori encontró {len(frequent_itemsets_apriori)} ")
# Out:
# Ejecutando Apriori...
# === OPTIMIZACIÓN DE MEMORIA ===
# Filtrando items poco frecuentes...
# Items originales: 31796
# Items frecuentes mantenidos: 1116
# Aplicando muestreo: 70.0% de las transacciones
# Transacciones: 8192 -> 5734
# Memoria inicial: 1606.46 MB
# Memoria después de conversión sparse: 1606.90 MB
#
# === EJECUTANDO APRIORI ===
# Dataset final: (5734, 1116)
# Memoria antes de Apriori: 1606.90 MB
# Processing 33 combinations | Sampling itemset size 2
#
# ✅ Apriori completado exitosamente!
# Conjuntos frecuentes encontrados: 451
# Memoria final: 1606.90 MB
# Apriori encontró 451

# %%
# # --- 4.1 Búsqueda de Ítems Frecuentes ---

# # Hiperparámetro a ajustar
# MIN_SUPPORT = 0.005

# # --- Algoritmo 1: Apriori ---
# print("Ejecutando Apriori...")

# frequent_itemsets_apriori = apriori(df_sparse,
#                         min_support=MIN_SUPPORT,      # tu umbral
#                         use_colnames=True,
#                         verbose=1,             # muestra el progreso
#                         low_memory=False)
# print(f"Apriori encontró {len(frequent_itemsets_apriori)} conjuntos de ítems frecuentes.")

# %% [markdown]
# Modo ultra-ligero para casos extremos:
#
# Muestreo súper agresivo (máximo 5000 transacciones)
# Solo top 50 items más frecuentes
# Máximo itemsets de tamaño 2
# porque no me carga

# %%
# 2) FP-Growth con restricciones
frequent_itemsets_fpgrowth =  run_fpgrowth_alternative(
                df_transactions,
                min_support=0.005,
                max_len=3)

# Mostramos los 10 más frecuentes encontrados por FP-Growth
print("\nTop 10 conjuntos de ítems más frecuentes:")
frequent_itemsets_fpgrowth.sort_values(by='support', ascending=False).head(10)
# Out:
# Intentando FP-Growth con optimizaciones extremas...
# Aplicando reducción extrema del dataset...
# Dataset ultra-reducido: (2700, 219)
# Memoria antes de FP-Growth: 2572.45 MB
# 219 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (62vpWI1CHwFy7tMIcSStl8)
# 0 itemset(s) from tree conditioned on items (27GmP9AWRs744SzKcpJsTZ)
# 0 itemset(s) from tree conditioned on items (439TlnnznSiBbQbgXiBqAd)
# 0 itemset(s) from tree conditioned on items (2FBUoWkIuQXwayw2RNo5l6)
# 0 itemset(s) from tree conditioned on items (25khomWgBVamSdKw7hzm3l)
# 0 itemset(s) from tree conditioned on items (2d8JP84HNLKhmd6IYOoupQ)
# 0 itemset(s) from tree conditioned on items (4w7yrP4RAeeyhfG9nJqQvS)
# 0 itemset(s) from tree conditioned on items (7wwifjNAb172PtDpKK3CoR)
# 0 itemset(s) from tree conditioned on items (0uMUvbkTdjBNZ5UuHZ5PIj)
# 0 itemset(s) from tree conditioned on items (5nN8BwAQDJDguq7Dpd3JQQ)
# 0 itemset(s) from tree conditioned on items (5lFDtgWsjRJu8fPOAyJIAK)
# 0 itemset(s) from tree conditioned on items (6fAyRZ0GHuuvSOEIOwi58N)
# 0 itemset(s) from tree conditioned on items (1AhDOtG9vPSOmsWgNW0BEY)
# 0 itemset(s) from tree conditioned on items (4BGJSbB5rAcg4pNzD4gfxU)
# 0 itemset(s) from tree conditioned on items (2zvot9pY2FNl1E94kc4K8M)
# 0 itemset(s) from tree conditioned on items (48UPSzbZjgc449aqz8bxox)
# 0 itemset(s) from tree conditioned on items (1mea3bSkSGXuIRvnydlB5b)
# 0 itemset(s) from tree conditioned on items (3n69hLUdIsSa1WlRmjMZlW)
# 0 itemset(s) from tree conditioned on items (6ZOBP3NvffbU4SZcrnt1k6)
# 0 itemset(s) from tree conditioned on items (7yyRTcZmCiyzzJlNzGC9Ol)
# 0 itemset(s) from tree conditioned on items (7KXjTSCq5nL1LoYtL7XAwS)
# 0 itemset(s) from tree conditioned on items (7BKLCZ1jbUBVqRi2FVlTVw)
# 1 itemset(s) from tree conditioned on items (0v9Wz8o0BT8DU38R4ddjeH)
# 0 itemset(s) from tree conditioned on items (3a1lNhkSLSkpJE4MSHpDu9)
# 0 itemset(s) from tree conditioned on items (0SGkqnVQo9KPytSri1H6cF)
# /usr/local/lib/python3.11/dist-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 1 itemset(s) from tree conditioned on items (0VgkVdmE4gld66l8iyGjgx)
# 0 itemset(s) from tree conditioned on items (152lZdxL1OR0ZMW6KquMif)
# 0 itemset(s) from tree conditioned on items (343YBumqHu19cGoGARUTsd)
# 0 itemset(s) from tree conditioned on items (0KKkJNfGyhkQ5aFogxQAPU)
# 0 itemset(s) from tree conditioned on items (2ANLarE8yHVsLWW21nj79M)
# 0 itemset(s) from tree conditioned on items (1f5cbQtDrykjarZVrShaDI)
# 0 itemset(s) from tree conditioned on items (6WhzFzROw3aq3rPWjgYlxr)
# 0 itemset(s) from tree conditioned on items (7KOlJ92bu51cltsD9KU5I7)
# 0 itemset(s) from tree conditioned on items (19a3JfW8BQwqHWUMbcqSx8)
# 0 itemset(s) from tree conditioned on items (5CtI0qwDJkDQGwXD1H1cLb)
# 0 itemset(s) from tree conditioned on items (7hDc8b7IXETo14hHIHdnhd)
# 0 itemset(s) from tree conditioned on items (20dP2DaMHIAmwWAbp7peSr)
# 0 itemset(s) from tree conditioned on items (4Q3N4Ct4zCuIHuZ65E3BD4)
# 0 itemset(s) from tree conditioned on items (6mapJIPnQ23RTAevUoE0DL)
# 0 itemset(s) from tree conditioned on items (6DNtNfH8hXkqOX1sjqmI7p)
# 0 itemset(s) from tree conditioned on items (6F609ICg9Spjrw1epsAnpa)
# 0 itemset(s) from tree conditioned on items (11KJSRSgaDxqydKYiD2Jew)
# 0 itemset(s) from tree conditioned on items (0dA2Mk56wEzDgegdC6R17g)
# 0 itemset(s) from tree conditioned on items (7qiZfU4dY1lWllzX7mPBI3)
# 0 itemset(s) from tree conditioned on items (2HbKqm4o0w5wEeEFXm2sD4)
# 0 itemset(s) from tree conditioned on items (3B54sVLJ402zGa6Xm4YGNe)
# 0 itemset(s) from tree conditioned on items (2bjwRfXMk4uRgOD9IBYl9h)
# 0 itemset(s) from tree conditioned on items (7DfFc7a6Rwfi3YQMRbDMau)
# 0 itemset(s) from tree conditioned on items (0Fv5N0cHBsl4bzCbollCAS)
# 0 itemset(s) from tree conditioned on items (2hKdd3qO7cWr2Jo0Bcs0MA)
# 0 itemset(s) from tree conditioned on items (7uKcScNXuO3MWw6LowBjW1)
# 0 itemset(s) from tree conditioned on items (0i5el041vd6nxrGEU8QRxy)
# 0 itemset(s) from tree conditioned on items (05ZACkzW8YbRq3eFgIfSNB)
# 0 itemset(s) from tree conditioned on items (1TKlBK9cSrM5u4CiL4SETS)
# 0 itemset(s) from tree conditioned on items (3b7CDTKB0SRTmQ6ytYi5vZ)
# 1 itemset(s) from tree conditioned on items (5kjyiH6but1t2UDXq15aeS)
# 0 itemset(s) from tree conditioned on items (03fT3OHB9KyMtGMt2zwqCT)
# 0 itemset(s) from tree conditioned on items (0yD66650JxhqKbW76C2qCo)
# 0 itemset(s) from tree conditioned on items (3pkzJjJXfdDjhpXx639MIH)
# 0 itemset(s) from tree conditioned on items (17Fd6Yb7mSbinKG8LoWfFl)
# 1 itemset(s) from tree conditioned on items (6HZILIRieu8S0iqY8kIKhj)
# 0 itemset(s) from tree conditioned on items (6Knv6wdA0luoMUuuoYi2i1)
# 0 itemset(s) from tree conditioned on items (7129iqBafaphfc3WPCGC0L)
# 0 itemset(s) from tree conditioned on items (12qZHAeOyTf93YAWvGDTat)
# 0 itemset(s) from tree conditioned on items (2TfSHkHiFO4gRztVIkggkE)
# 0 itemset(s) from tree conditioned on items (5qqabIl2vWzo9ApSC317sa)
# 0 itemset(s) from tree conditioned on items (5ghIJDpPoe3CfHMGu71E6T)
# 0 itemset(s) from tree conditioned on items (0d8ZbnRoW1TJ3qEleTrYHH)
# 0 itemset(s) from tree conditioned on items (3d9DChrdc6BOeFsbrZ3Is0)
# 0 itemset(s) from tree conditioned on items (5XJJdNPkwmbUwE79gv0NxK)
# 0 itemset(s) from tree conditioned on items (6RcQOut9fWL6FSqeIr5M1r)
# 0 itemset(s) from tree conditioned on items (6O6M7pJLABmfBRoGZMu76Y)
# 0 itemset(s) from tree conditioned on items (0QsvXIfqM0zZoerQfsI9lm)
# 0 itemset(s) from tree conditioned on items (1Tt4sE4pXi57mTD1GCzsqm)
# 0 itemset(s) from tree conditioned on items (7vRriwrloYVaoAe3a9wJHe)
# 0 itemset(s) from tree conditioned on items (6JV2JOEocMgcZxYSZelKcc)
# 0 itemset(s) from tree conditioned on items (5kNe7PE09d6Kvw5pAsx23n)
# 0 itemset(s) from tree conditioned on items (5HGibWoxnkYSkl6mHmAlOE)
# 0 itemset(s) from tree conditioned on items (3xdjjKMcMOFgo1eQrfbogM)
# 0 itemset(s) from tree conditioned on items (1soxUgYIZb1qx1c7o1Lc7z)
# 0 itemset(s) from tree conditioned on items (5OOkp4U9P9oL23maHFHL1h)
# 0 itemset(s) from tree conditioned on items (40YcuQysJ0KlGQTeGUosTC)
# 0 itemset(s) from tree conditioned on items (19gEmPjfqSZT0ulDRfjl0m)
# 0 itemset(s) from tree conditioned on items (0yhPEz5KxlDwckGJaMlZqM)
# 0 itemset(s) from tree conditioned on items (1xznGGDReH1oQq0xzbwXa3)
# 0 itemset(s) from tree conditioned on items (2Z8WuEywRWYTKe1NybPQEW)
# 1 itemset(s) from tree conditioned on items (5uDASfU19gDxSjW8cnCaBp)
# 0 itemset(s) from tree conditioned on items (2PpruBYCo4H7WOBJ7Q2EwM)
# 0 itemset(s) from tree conditioned on items (4pdPtRcBmOSQDlJ3Fk945m)
# 0 itemset(s) from tree conditioned on items (12REd1n8PeiHHWOh066tpr)
# 0 itemset(s) from tree conditioned on items (4RCWB3V8V0dignt99LZ8vH)
# 0 itemset(s) from tree conditioned on items (7EiZI6JVHllARrX9PUvAdX)
# 0 itemset(s) from tree conditioned on items (43PuMrRfbyyuz4QpZ3oAwN)
# 0 itemset(s) from tree conditioned on items (5yuShbu70mtHXY0yLzCQLQ)
# 0 itemset(s) from tree conditioned on items (1wZqJM5FGDEl3FjHDxDyQd)
# 0 itemset(s) from tree conditioned on items (7yq4Qj7cqayVTp3FF9CWbm)
# 0 itemset(s) from tree conditioned on items (5edBgVtRD0fvWk140Sl21T)
# 0 itemset(s) from tree conditioned on items (3lSR267IJfT54p0Gfuw7mi)
# 0 itemset(s) from tree conditioned on items (5OMwQFBcte0aWFJFqrr5oj)
# 0 itemset(s) from tree conditioned on items (2dOTkLZFbpNXrhc24CnTFd)
# 0 itemset(s) from tree conditioned on items (4jtyUzZm9WLc2AdaJ1dso7)
# 0 itemset(s) from tree conditioned on items (4Kz4RdRCceaA9VgTqBhBfa)
# 0 itemset(s) from tree conditioned on items (6V2D8Lls36APk0THDjBDfE)
# 0 itemset(s) from tree conditioned on items (4bPQs0PHn4xbipzdPfn6du)
# 0 itemset(s) from tree conditioned on items (6ihL9TjfRjadfEePzXXyVF)
# 0 itemset(s) from tree conditioned on items (5lDriBxJd22IhOH9zTcFrV)
# 0 itemset(s) from tree conditioned on items (0wdKiSBUT7aZkXUIdJWcwC)
# 0 itemset(s) from tree conditioned on items (0zO8ctW0UiuOefR87OeJOZ)
# 0 itemset(s) from tree conditioned on items (3DXncPQOG4VBw3QHh3S817)
# 0 itemset(s) from tree conditioned on items (4kbj5MwxO1bq9wjT5g9HaA)
# 0 itemset(s) from tree conditioned on items (6YbhspuOar1D9WSSnfe7ds)
# 0 itemset(s) from tree conditioned on items (5iSEsR6NKjlC9SrIJkyL3k)
# 2 itemset(s) from tree conditioned on items (4Km5HrUvYTaSUfiSGPJeQR)
# 0 itemset(s) from tree conditioned on items (4Km5HrUvYTaSUfiSGPJeQR, 7yyRTcZmCiyzzJlNzGC9Ol)
# 0 itemset(s) from tree conditioned on items (4Km5HrUvYTaSUfiSGPJeQR, 0SGkqnVQo9KPytSri1H6cF)
# 0 itemset(s) from tree conditioned on items (2EEeOnHehOozLq4aS0n6SL)
# 0 itemset(s) from tree conditioned on items (6fujklziTHa8uoM5OQSfIo)
# 0 itemset(s) from tree conditioned on items (03tqyYWC9Um2ZqU0ZN849H)
# 0 itemset(s) from tree conditioned on items (2LvRR121MWFmmEGkuV2vQP)
# 0 itemset(s) from tree conditioned on items (0Y0TOsE1q11qgbi7c5WZsG)
# 0 itemset(s) from tree conditioned on items (5Q0Nhxo0l2bP3pNjpGJwV1)
# 0 itemset(s) from tree conditioned on items (5mPSyjLatqB00IkPqRlbTE)
# 0 itemset(s) from tree conditioned on items (6RsWqX8zABZLhZydXxEFOm)
# 0 itemset(s) from tree conditioned on items (6hmhG1b4LEyNuashVvuIAo)
# 0 itemset(s) from tree conditioned on items (6rbeWjEavBHvX2kr6lSogS)
# 0 itemset(s) from tree conditioned on items (4tCtwWceOPWzenK2HAIJSb)
# 0 itemset(s) from tree conditioned on items (1UZ25gykR30Oewh3dBRtVZ)
# 0 itemset(s) from tree conditioned on items (0Dc7J9VPV4eOInoxUiZrsL)
# 1 itemset(s) from tree conditioned on items (7GX5flRQZVHRAGd6B4TmDO)
# 0 itemset(s) from tree conditioned on items (6p8NuHm8uCGnn2Dtbtf7zE)
# 0 itemset(s) from tree conditioned on items (5KY7zgFeH2GWoL1zP9mME6)
# 0 itemset(s) from tree conditioned on items (4uhvMW7ly7tJil31YYscAN)
# 0 itemset(s) from tree conditioned on items (3ts6xK5GzfMAAriT9AIBmP)
# 0 itemset(s) from tree conditioned on items (5aAx2yezTd8zXrkmtKl66Z)
# 0 itemset(s) from tree conditioned on items (40yJGQyEaBbIkXpwMFkXip)
# 0 itemset(s) from tree conditioned on items (6ZYS6QQxTLsQ6IFXdVx1r4)
# 0 itemset(s) from tree conditioned on items (2KpCpk6HjXXLb7nnXoXA5O)
# 0 itemset(s) from tree conditioned on items (1wHZx0LgzFHyeIZkUydNXq)
# 0 itemset(s) from tree conditioned on items (16qYlQ6koFxYVbiJbGHblz)
# 0 itemset(s) from tree conditioned on items (5uCax9HTNlzGybIStD3vDh)
# 0 itemset(s) from tree conditioned on items (6REbwUNlppTfcnV4d4ZoZi)
# 0 itemset(s) from tree conditioned on items (20LxTsa6936zOlzTWqoPVt)
# 0 itemset(s) from tree conditioned on items (4gFXY5yvHayGckJndafYQE)
# 0 itemset(s) from tree conditioned on items (4llK75pXNWZz6KAho2Gp16)
# 0 itemset(s) from tree conditioned on items (2CvOqDpQIMw69cCzWqr5yr)
# 0 itemset(s) from tree conditioned on items (4KW1lqgSr8TKrvBII0Brf8)
# 0 itemset(s) from tree conditioned on items (0IqKeD8ZSP72KbGYyzEcAs)
# 0 itemset(s) from tree conditioned on items (1jdNcAD8Ir58RlsdGjJJdx)
# 0 itemset(s) from tree conditioned on items (5Z3GHaZ6ec9bsiI5BenrbY)
# 0 itemset(s) from tree conditioned on items (5fVZC9GiM4e8vu99W0Xf6J)
# 0 itemset(s) from tree conditioned on items (4dGJf1SER1T6ooX46vwzRB)
# 0 itemset(s) from tree conditioned on items (2TR7A4ulH9R1PNwMyd8o8U)
# 0 itemset(s) from tree conditioned on items (3NxAG2ni1lLa8RKL6a0INc)
# 0 itemset(s) from tree conditioned on items (2FviG1Ma0M0BSZbqaDvw0x)
# 0 itemset(s) from tree conditioned on items (1zWZvrk13cL8Sl3VLeG57F)
# 0 itemset(s) from tree conditioned on items (0O45fw2L5vsWpdsOdXwNAR)
# 0 itemset(s) from tree conditioned on items (1Slwb6dOYkBlWal1PGtnNg)
# 0 itemset(s) from tree conditioned on items (6g1NlCpW7fgqDnWbCCDrHl)
# 0 itemset(s) from tree conditioned on items (6gBFPUFcJLzWGx4lenP6h2)
# 0 itemset(s) from tree conditioned on items (6C7RJEIUDqKkJRZVWdkfkH)
# 0 itemset(s) from tree conditioned on items (0B8QzDH7YWih85V5SEMnyJ)
# 0 itemset(s) from tree conditioned on items (2rzBvHM9h36Tpdj7Jdajka)
# 0 itemset(s) from tree conditioned on items (49zD0wr2S3d0lZPib0K4e1)
# 0 itemset(s) from tree conditioned on items (7oK9VyNzrYvRFo7nQEYkWN)
# 0 itemset(s) from tree conditioned on items (0XUfyU2QviPAs6bxSpXYG4)
# 0 itemset(s) from tree conditioned on items (6fwdbPMwP1zVStm8FybmkO)
# 0 itemset(s) from tree conditioned on items (3pXF1nA74528Edde4of9CC)
# 0 itemset(s) from tree conditioned on items (3CRDbSIZ4r5MsZ0YwxuEkn)
# 0 itemset(s) from tree conditioned on items (7mldq42yDuxiUNn08nvzHO)
# 0 itemset(s) from tree conditioned on items (5InOp6q2vvx0fShv3bzFLZ)
# 0 itemset(s) from tree conditioned on items (14WWzenpaEgQZlqPq2nk4v)
# 0 itemset(s) from tree conditioned on items (3hB5DgAiMAQ4DzYbsMq1IT)
# 0 itemset(s) from tree conditioned on items (0L7loeTIg6akW84aEQZpCT)
# 0 itemset(s) from tree conditioned on items (3bidbhpOYeV4knp8AIu8Xn)
# 0 itemset(s) from tree conditioned on items (6Ep6BzIOB9tz3P4sWqiiAB)
# 0 itemset(s) from tree conditioned on items (3ZFTkvIE7kyPt6Nu3PEa7V)
# 0 itemset(s) from tree conditioned on items (3ESSGgWzRf1xvP7G5hHMhB)
# 0 itemset(s) from tree conditioned on items (53gcDgFyqqpvCzXWrnFZpH)
# 0 itemset(s) from tree conditioned on items (2kQuhkFX7uSVepCD3h29g5)
# 0 itemset(s) from tree conditioned on items (5hTpBe8h35rJ67eAWHQsJx)
# 0 itemset(s) from tree conditioned on items (4WjH9Bzt3kx7z8kl0awxh4)
# 0 itemset(s) from tree conditioned on items (6vnDoUOHTiVB5DvX18tJon)
# 0 itemset(s) from tree conditioned on items (7w87IxuO7BDcJ3YUqCyMTT)
# 0 itemset(s) from tree conditioned on items (1eyzqe2QqGZUmfcPZtrIyt)
# 0 itemset(s) from tree conditioned on items (5tz69p7tJuGPeMGwNTxYuV)
# 0 itemset(s) from tree conditioned on items (4bHsxqR3GMrXTxEPLuK5ue)
# 0 itemset(s) from tree conditioned on items (5dNfHmqgr128gMY2tc5CeJ)
# 0 itemset(s) from tree conditioned on items (0CAfXk7DXMnon4gLudAp7J)
# 0 itemset(s) from tree conditioned on items (06iMqWThw4w8fTFyccvOwr)
# 0 itemset(s) from tree conditioned on items (70cTMpcgWMcR18t9MRJFjB)
# 0 itemset(s) from tree conditioned on items (6eT7xZZlB2mwyzJ2sUKG6w)
# 0 itemset(s) from tree conditioned on items (4jTiyLlOJVJj3mCr7yfPQD)
# 0 itemset(s) from tree conditioned on items (7FOJvA3PxiIU0DN3JjQ7jT)
# 0 itemset(s) from tree conditioned on items (5NQbUaeTEOGdD6hHcre0dZ)
# 0 itemset(s) from tree conditioned on items (1Ser4X0TKttOvo8bgdytTP)
# 0 itemset(s) from tree conditioned on items (1WoOzgvz6CgH4pX6a1RKGp)
# 0 itemset(s) from tree conditioned on items (4scpF6J5uMBvoh6sFB7EL1)
# 0 itemset(s) from tree conditioned on items (7xVLFuuYdAvcTfcP3IG3dS)
# 0 itemset(s) from tree conditioned on items (7H6ev70Weq6DdpZyyTmUXk)
# 0 itemset(s) from tree conditioned on items (6TaqooOXAEcijL6G1AWS2K)
# 0 itemset(s) from tree conditioned on items (4OZEu0Vwq0RB2LAq14v99n)
# 0 itemset(s) from tree conditioned on items (3kxfsdsCpFgN412fpnW85Y)
# 0 itemset(s) from tree conditioned on items (40riOy7x9W7GXjyGp4pjAv)
# 0 itemset(s) from tree conditioned on items (78WVLOP9pN0G3gRLFy1rAa)
# 0 itemset(s) from tree conditioned on items (5MxNLUsfh7uzROypsoO5qe)
# 0 itemset(s) from tree conditioned on items (4Pwjz3DfvfQWV0rO2V8jyh)
# 0 itemset(s) from tree conditioned on items (047fCsbO4NdmwCBn8pcUXl)
# 0 itemset(s) from tree conditioned on items (4kNvYhyl8R6m1vykVkcuBu)
# 0 itemset(s) from tree conditioned on items (1WP1r7fuvRqZRnUaTi2I1Q)
# 0 itemset(s) from tree conditioned on items (0PJIbOdMs3bd5AT8liULMQ)
# 0 itemset(s) from tree conditioned on items (7o2CTH4ctstm8TNelqjb51)
# 0 itemset(s) from tree conditioned on items (2l57cfmCnOkwNX1tky02n1)
# 0 itemset(s) from tree conditioned on items (4CJVkjo5WpmUAKp3R44LNb)
# 0 itemset(s) from tree conditioned on items (69bp2EbF7Q2rqc5N3ylezZ)
# 0 itemset(s) from tree conditioned on items (5SqSckut3FcoQKmGkMWgp1)
# 0 itemset(s) from tree conditioned on items (1lzr43nnXAijIGYnCT8M8H)
# 0 itemset(s) from tree conditioned on items (32OlwWuMpZ6b0aN2RZOeMS)
# 0 itemset(s) from tree conditioned on items (4X5f3vT8MRuXF68pfjNte5)
# 0 itemset(s) from tree conditioned on items (1KGi9sZVMeszgZOWivFpxs)
# 0 itemset(s) from tree conditioned on items (0azC730Exh71aQlOt9Zj3y)
# 0 itemset(s) from tree conditioned on items (7tr2za8SQg2CI8EDgrdtNl)
# ✅ FP-Growth completado con dataset reducido!
# Conjuntos frecuentes encontrados: 227
#
# Top 10 conjuntos de ítems más frecuentes:
#       support                  itemsets
# 19   0.025556  (7yyRTcZmCiyzzJlNzGC9Ol)
# 84   0.024074  (1xznGGDReH1oQq0xzbwXa3)
# 0    0.022963  (62vpWI1CHwFy7tMIcSStl8)
# 20   0.022593  (7KXjTSCq5nL1LoYtL7XAwS)
# 12   0.022593  (1AhDOtG9vPSOmsWgNW0BEY)
# 69   0.022593  (5XJJdNPkwmbUwE79gv0NxK)
# 1    0.021852  (27GmP9AWRs744SzKcpJsTZ)
# 21   0.021111  (7BKLCZ1jbUBVqRi2FVlTVw)
# 134  0.021111  (2KpCpk6HjXXLb7nnXoXA5O)
# 184  0.021111  (5dNfHmqgr128gMY2tc5CeJ)

# %%
frequent_itemsets_apriori.sort_values(by='support', ascending=False).head(10)
# Out:
#       support                  itemsets
# 982  0.026190  (7yyRTcZmCiyzzJlNzGC9Ol)
# 652  0.025397  (5XJJdNPkwmbUwE79gv0NxK)
# 666  0.025079  (5dNfHmqgr128gMY2tc5CeJ)
# 732  0.023810  (62vpWI1CHwFy7tMIcSStl8)
# 918  0.022698  (7KXjTSCq5nL1LoYtL7XAwS)
# 895  0.022381  (7BKLCZ1jbUBVqRi2FVlTVw)
# 263  0.022222  (27GmP9AWRs744SzKcpJsTZ)
# 101  0.022222  (0v9Wz8o0BT8DU38R4ddjeH)
# 235  0.021587  (1xznGGDReH1oQq0xzbwXa3)
# 513  0.020952  (4Km5HrUvYTaSUfiSGPJeQR)

# %%
frequent_itemsets_fpgrowth.sort_values(by='support', ascending=False).head(10)
# Out:
#       support                  itemsets
# 19   0.025556  (7yyRTcZmCiyzzJlNzGC9Ol)
# 84   0.024074  (1xznGGDReH1oQq0xzbwXa3)
# 0    0.022963  (62vpWI1CHwFy7tMIcSStl8)
# 20   0.022593  (7KXjTSCq5nL1LoYtL7XAwS)
# 12   0.022593  (1AhDOtG9vPSOmsWgNW0BEY)
# 69   0.022593  (5XJJdNPkwmbUwE79gv0NxK)
# 1    0.021852  (27GmP9AWRs744SzKcpJsTZ)
# 21   0.021111  (7BKLCZ1jbUBVqRi2FVlTVw)
# 134  0.021111  (2KpCpk6HjXXLb7nnXoXA5O)
# 184  0.021111  (5dNfHmqgr128gMY2tc5CeJ)

# %%
#codigo para mostrar en la terminal las caracterisiticas del RAM y CPU disponible
import psutil

# Mostrar características de la CPU
print("Características de la CPU:")
print(f"Núcleos: {psutil.cpu_count(logical=False)}")
print(f"Frecuencia: {psutil.cpu_freq().current} MHz")

# Mostrar características de la RAM
print("\nCaracterísticas de la RAM:")
print(f"Total: {psutil.virtual_memory().total / (1024 ** 3):.2f} GB")
# Out:
# Características de la CPU:
# Núcleos: 1
# Frecuencia: 2000.222 MHz
#
# Características de la RAM:
# Total: 12.67 GB

# %% [markdown]
# ### 4.2 Generar y Analizar Reglas de Asociación
# A partir de los conjuntos frecuentes, generamos las reglas. Nos interesan principalmente dos métricas:
#
# Confianza (Confidence): La probabilidad de encontrar el item B si ya tienes el item A.
# Lift: Mide cuánto más probable es encontrar B si tienes A, en comparación con la probabilidad de encontrar B por sí solo. Un lift > 1 indica una asociación positiva.

# %%
from mlxtend.frequent_patterns import association_rules

# --- reglas completas ---
rules = association_rules(frequent_itemsets_fpgrowth,
                          metric="confidence", min_threshold=0.1)

# 1) Filtro inicial
sig = rules[(rules['lift'] > 1.5) & (rules['confidence'] > 0.2)].copy()

# 2) Clave canónica = antecedentes ∪ consecuentes (ordenado)
sig['pair_key'] = sig.apply(
    lambda r: frozenset(r['antecedents'] | r['consequents']),
    axis=1
)

# 3) Ordena por la métrica que quieras privilegiar
significant_rules = sig.sort_values('lift', ascending=False)   # o 'confidence'

# 4) Quita duplicados usando la clave
significant_rules = sig.drop_duplicates(subset='pair_key', keep='first').reset_index(drop=True)

print(f"Se generaron {len(rules)} reglas en total.")
print(f"Se encontraron {len(significant_rules)} reglas significativas sin duplicados.\n")

print("Top 5 reglas de asociación (sin repeticiones por espejo):")
display(significant_rules.head(5))
# Out:
# Se generaron 16 reglas en total.
# Se encontraron 8 reglas significativas sin duplicados.
#
# Top 5 reglas de asociación (sin repeticiones por espejo):
#                 antecedents               consequents  antecedent support  \
# 0  (7yyRTcZmCiyzzJlNzGC9Ol)  (0v9Wz8o0BT8DU38R4ddjeH)            0.025556
# 1  (7KXjTSCq5nL1LoYtL7XAwS)  (0VgkVdmE4gld66l8iyGjgx)            0.022593
# 2  (5kjyiH6but1t2UDXq15aeS)  (4dGJf1SER1T6ooX46vwzRB)            0.010741
# 3  (7KXjTSCq5nL1LoYtL7XAwS)  (6HZILIRieu8S0iqY8kIKhj)            0.022593
# 4  (7yyRTcZmCiyzzJlNzGC9Ol)  (5uDASfU19gDxSjW8cnCaBp)            0.025556
#
#    consequent support   support  confidence       lift  representativity  \
# 0            0.020370  0.009259    0.362319  17.786561               1.0
# 1            0.017778  0.008889    0.393443  22.131148               1.0
# 2            0.013333  0.008519    0.793103  59.482759               1.0
# 3            0.014444  0.008148    0.360656  24.968474               1.0
# 4            0.017037  0.008148    0.318841  18.714556               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0  0.008739    1.536237       0.968529  0.252525   0.349059    0.408432
# 1  0.008487    1.619339       0.976885  0.282353   0.382464    0.446721
# 2  0.008375    4.768889       0.993863  0.547619   0.790308    0.715996
# 3  0.007822    1.541510       0.982139  0.282051   0.351285    0.462379
# 4  0.007713    1.443073       0.971390  0.236559   0.307035    0.398551
#
#                                            pair_key
# 0  (7yyRTcZmCiyzzJlNzGC9Ol, 0v9Wz8o0BT8DU38R4ddjeH)
# 1  (7KXjTSCq5nL1LoYtL7XAwS, 0VgkVdmE4gld66l8iyGjgx)
# 2  (5kjyiH6but1t2UDXq15aeS, 4dGJf1SER1T6ooX46vwzRB)
# 3  (7KXjTSCq5nL1LoYtL7XAwS, 6HZILIRieu8S0iqY8kIKhj)
# 4  (7yyRTcZmCiyzzJlNzGC9Ol, 5uDASfU19gDxSjW8cnCaBp)

# %% [markdown]
# ### 4.3 Entregables (CSV y Gráfico de Red)

# %%
# --- 4.3 Entregables ---

# 1. Guardar las reglas en un archivo CSV
rules_output_path = Path("data/results")
rules_output_path.mkdir(parents=True, exist_ok=True)
significant_rules.to_csv(rules_output_path / "reglas_asociacion_significativas.csv", index=False)
print(f"Reglas guardadas en '{rules_output_path / 'reglas_asociacion_significativas.csv'}'")


# 2. Visualización: Gráfico de Red de las 20 reglas principales
# (Puede ser lento si hay muchas reglas)
top_rules = significant_rules.head(20)

plt.figure(figsize=(15, 15))
G = nx.from_pandas_edgelist(top_rules,
                           source='antecedents',
                           target='consequents',
                           edge_attr=['lift', 'confidence'])

# Posiciones de los nodos
pos = nx.spring_layout(G, k=0.5, iterations=50)

# Dibujar nodos y etiquetas
nx.draw_networkx_nodes(G, pos, node_size=2000, node_color='skyblue')
nx.draw_networkx_labels(G, pos, font_size=8)

# Dibujar aristas con grosor basado en el lift
edge_width = [d['lift'] * 0.5 for (u, v, d) in G.edges(data=True)]
nx.draw_networkx_edges(G, pos, width=edge_width, edge_color='gray', alpha=0.7)

plt.title('Red de Reglas de Asociación (Top 20 por Lift)')
plt.axis('off')
plt.show()
# Out:
# Reglas guardadas en 'data/results/reglas_asociacion_significativas.csv'

# %%
UMAP_tracks = tracks_umap.copy()
UMAP_tracks_numeric = UMAP_tracks.select_dtypes(include=np.number)
# Basado en el gráfico, elegimos un valor para k (ej. k=8 donde la curva se aplana)
OPTIMAL_K = 5
kmeans = KMeans(n_clusters=OPTIMAL_K, random_state=42, n_init=10)
# Usamos el DataFrame NUMÉRICO aquí también
track_labels_kmeans = kmeans.fit_predict(UMAP_tracks_numeric)

print(f"\nClustering con K-Means completado usando k={OPTIMAL_K}.")
# --- 5.A.2 Algoritmos 2 y 3: DBSCAN y MiniBatchKMeans (CORREGIDO Y OPTIMIZADO) ---

# --- DBSCAN ---
# DBSCAN puede ser lento en datasets grandes. Sus hiperparámetros son clave.
# Si esta parte también es muy lenta, considera ejecutarla sobre una muestra o ajustar 'eps'.
print("Ejecutando DBSCAN...")
dbscan = DBSCAN(eps=2.5, min_samples=20, n_jobs=-1) # n_jobs=-1 usa todos los núcleos de tu CPU
track_labels_dbscan = dbscan.fit_predict(UMAP_tracks_numeric)
print("DBSCAN completado.")


# --- MiniBatchKMeans (Reemplazo eficiente para Agglomerative Clustering) ---
# Este algoritmo es mucho más rápido y consume muchísima menos memoria.
print("Ejecutando MiniBatchKMeans...")
mini_batch_kmeans = MiniBatchKMeans(
    n_clusters=OPTIMAL_K, # Usamos el mismo k que en KMeans
    random_state=42,
    batch_size=256, # Tamaño del lote, un hiperparámetro a ajustar
    n_init=10
)
track_labels_minibatch = mini_batch_kmeans.fit_predict(UMAP_tracks_numeric)
print("MiniBatchKMeans completado.")

# --- 5.A.3 Evaluación Comparativa y Visualización (MODIFICADO Y CORREGIDO) ---

print("\nCalculando métricas de evaluación...")

# --- K-Means ---
# CORREGIDO: Usamos X_tracks_numeric para el cálculo de los scores.
print("Evaluando K-Means...")
score_s_kmeans = silhouette_score(UMAP_tracks_numeric, track_labels_kmeans)
score_db_kmeans = davies_bouldin_score(UMAP_tracks_numeric, track_labels_kmeans)

# --- DBSCAN ---
# CORREGIDO: Usamos X_tracks_numeric y mantenemos la optimización de muestreo para el cálculo.
print("Evaluando DBSCAN...")
mask_dbscan = track_labels_dbscan != -1 # Filtro para excluir puntos de ruido (label -1)

# Nos aseguramos de que DBSCAN haya encontrado más de 1 clúster para poder evaluar
if len(set(track_labels_dbscan[mask_dbscan])) > 1:
    # Usamos una muestra para que el cálculo del score sea rápido en datasets grandes
    # Tomamos una muestra de hasta 20,000 puntos que no sean ruido
    sample_size = min(20000, np.sum(mask_dbscan))

    # --- FIX START ---
    # Reset the index of X_tracks_numeric to allow for integer indexing
    UMAP_tracks_numeric_reset = UMAP_tracks_numeric.reset_index(drop=True)
    # Use the index of the filtered data (mask_dbscan) to sample from the reset DataFrame
    sample_indices = np.random.choice(UMAP_tracks_numeric_reset[mask_dbscan].index, size=sample_size, replace=False)

    score_s_dbscan = silhouette_score(UMAP_tracks_numeric_reset.loc[sample_indices], track_labels_dbscan[sample_indices])
    score_db_dbscan = davies_bouldin_score(UMAP_tracks_numeric_reset.loc[sample_indices], track_labels_dbscan[sample_indices])
    # --- FIX END ---
else:
    # If DBSCAN no encontró clusters (o solo uno), asignamos un score inválido
    print("DBSCAN no encontró suficientes clusters para ser evaluado.")
    score_s_dbscan = -1
    score_db_dbscan = -1

# --- MiniBatchKMeans ---
# NUEVO: Reemplazamos la evaluación de Agglomerative por la de MiniBatchKMeans.
print("Evaluando MiniBatchKMeans...")
score_s_minibatch = silhouette_score(UMAP_tracks_numeric, track_labels_minibatch)
score_db_minibatch = davies_bouldin_score(UMAP_tracks_numeric, track_labels_minibatch)


# --- Crear tabla de resultados ---
# CORREGIDO: Actualizamos la lista de algoritmos y las variables de los scores.
results = pd.DataFrame({
    'Algoritmo': ['K-Means', 'DBSCAN', 'MiniBatchKMeans'],
    'Silhouette Score (más alto es mejor)': [score_s_kmeans, score_s_dbscan, score_s_minibatch],
    'Davies-Bouldin Score (más bajo es mejor)': [score_db_kmeans, score_db_dbscan, score_db_minibatch]
})

print("\n--- Tabla Comparativa de Modelos de Clustering de Tracks ---")
display(results)


# --- Visualización de Clusters ---
# Este bloque no necesita cambios, pero lo mantenemos por completitud.
# Muestra los resultados de K-Means como ejemplo.
# Nota: Para visualizar otros resultados, simplemente cambia 'track_labels_kmeans'
# por 'track_labels_minibatch' o 'track_labels_dbscan'.

print("\nGenerando visualización de clusters (ejemplo con K-Means)...")
viz_df = tracks_umap.copy()
viz_df['cluster'] = track_labels_kmeans

plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=viz_df,
    x='UMAP_1',
    y='UMAP_2',
    hue='cluster',
    palette=sns.color_palette("hsv", n_colors=OPTIMAL_K),
    s=10, # Tamaño de los puntos
    alpha=0.7,
    legend='full'
)
plt.title(f'Visualización de Clusters de Canciones (K-Means, k={OPTIMAL_K})')
plt.show()
# Out:
# Clustering con K-Means completado usando k=5.
# Ejecutando DBSCAN...
# DBSCAN completado.
# Ejecutando MiniBatchKMeans...
# MiniBatchKMeans completado.
#
# Calculando métricas de evaluación...
# Evaluando K-Means...
# Evaluando DBSCAN...
# DBSCAN no encontró suficientes clusters para ser evaluado.
# Evaluando MiniBatchKMeans...
#
# --- Tabla Comparativa de Modelos de Clustering de Tracks ---
#          Algoritmo  Silhouette Score (más alto es mejor)  \
# 0          K-Means                              0.393663
# 1           DBSCAN                             -1.000000
# 2  MiniBatchKMeans                              0.377706
#
#    Davies-Bouldin Score (más bajo es mejor)
# 0                                  0.850035
# 1                                 -1.000000
# 2                                  0.861170
# Generando visualización de clusters (ejemplo con K-Means)...
